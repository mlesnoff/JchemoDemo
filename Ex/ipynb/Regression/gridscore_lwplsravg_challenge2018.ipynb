# %%
using JLD2, CairoMakie, StatsBase
using Jchemo, JchemoData
using FreqTables

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/challenge2018.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot, p = size(X)
# Out:
# (4075, 680)

# %%
@head X
# Out:
# ... (4075, 680)
# 3×680 DataFrame
#  Row │ 1120      1122      1124      1126      1128      1130      1132      1 ⋯
#      │ Float64   Float64   Float64   Float64   Float64   Float64   Float64   F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 0.597482  0.595978  0.593623  0.59084   0.587451  0.583092  0.578666  0 ⋯
#    2 │ 0.954192  0.953237  0.952002  0.950426  0.948382  0.946138  0.943543  0
#    3 │ 0.611137  0.609566  0.60743   0.604767  0.601434  0.597316  0.592598  0
#                                                              673 columns omitted

# %%
@head Y
# Out:
# ... (4075, 4)
# 3×4 DataFrame
#  Row │ typ     label               conc     test
#      │ String  String              Float64  Int64
# ─────┼────────────────────────────────────────────
#    1 │ FRG     wheat (ung)         12.74        0
#    2 │ MPW     milk powder & whey  35.7212      0
#    3 │ FRG     wheat (ung)         12.0         0

# %%
summ(Y)
# Out:
# (res = 4×7 DataFrame
#  Row │ variable  mean    std     min          max          n      nmissing
#      │ Symbol    Union…  Union…  Any          Any          Int64  Int64
# ─────┼─────────────────────────────────────────────────────────────────────
#    1 │ typ                       ANF          TTS           4075         0
#    2 │ label                     animal feed  wheat (ung)   4075         0
#    3 │ conc      31.93   20.348  2.766        76.604        4075         0
#    4 │ test      0.092   0.289   0            1             4075         0, ntot = 4075)

# %%
y = Y.conc
typ = Y.typ
label = Y.label
test = Y.test
tab(test)
# Out:
# OrderedCollections.OrderedDict{Int64, Int64} with 2 entries:
#   0 => 3701
#   1 => 374

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 680-element Vector{Float64}:
#  1120.0
#  1122.0
#  1124.0
#  1126.0
#  1128.0
#  1130.0
#  1132.0
#  1134.0
#  1136.0
#  1138.0
#     ⋮
#  2462.0
#  2464.0
#  2466.0
#  2468.0
#  2470.0
#  2472.0
#  2474.0
#  2476.0
#  2478.0

# %%
freqtable(string.(typ, "-", Y.label))
# Out:
# 10-element Named Vector{Int64}
# Dim1                    │
# ────────────────────────┼────
# ANF-animal feed         │ 391
# CLZ-rapeseed(ung)       │ 420
# CNG-corn gluten         │ 395
# EHH-grass silage        │ 422
# FFS-full fat soya       │ 432
# FRG-wheat (ung)         │ 411
# MPW-milk powder & whey  │ 410
# PEE-maize wp            │ 407
# SFG-sun flower seed(gr) │ 281
# TTS-soya meal           │ 506

# %%
freqtable(typ, test)
# Out:
# 10×2 Named Matrix{Int64}
# Dim1 ╲ Dim2 │   0    1
# ────────────┼─────────
# ANF         │ 351   40
# CLZ         │ 378   42
# CNG         │ 356   39
# EHH         │ 380   42
# FFS         │ 397   35
# FRG         │ 371   40
# MPW         │ 372   38
# PEE         │ 367   40
# SFG         │ 272    9
# TTS         │ 457   49

# %%
plotsp(X, wl_num; nsamp = 30).f
# Out:
# Figure()

# %%
f = 21 ; pol = 3 ; d = 2
Xp = savgol(snv(X); f = f, pol = pol, d = d) ;

plotsp(Xp, wl_num; nsamp = 30).f
# Out:
# Figure()

# %%
s = Bool.(test)
Xtrain = rmrow(Xp, s)
ytrain = rmrow(y, s)
Xtest = Xp[s, :]
ytest = y[s]
ntrain = nro(Xtrain)
ntest = nro(Xtest)
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 4075, ntrain = 3701, ntest = 374)

# %%
nval = 300
ncal = ntrain - nval
s = sample(1:ntrain, nval; replace = false)
Xcal = rmrow(Xtrain, s)
ycal = rmrow(ytrain, s)
Xval = Xtrain[s, :]
yval = ytrain[s]
(ntot = ntot, ntrain, ntest, ncal, nval)
# Out:
# (ntot = 4075, ntrain = 3701, ntest = 374, ncal = 3401, nval = 300)

# %%
nlvdis = [15; 25] ; metric = ["mahal"]
h = [1; 2.5; 5]
k = [200; 350; 500]
nlv = ["0:20"; "5:20"; "0:30"; "5:30"]
pars = mpar(nlvdis = nlvdis, metric = metric,
    h = h, k = k, nlv = nlv)
# Out:
# (nlvdis = Any[15, 25, 15, 25, 15, 25, 15, 25, 15, 25  …  15, 25, 15, 25, 15, 25, 15, 25, 15, 25], metric = Any["mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"  …  "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"], h = Any[1.0, 1.0, 2.5, 2.5, 5.0, 5.0, 1.0, 1.0, 2.5, 2.5  …  2.5, 2.5, 5.0, 5.0, 1.0, 1.0, 2.5, 2.5, 5.0, 5.0], k = Any[200, 200, 200, 200, 200, 200, 350, 350, 350, 350  …  350, 350, 350, 350, 500, 500, 500, 500, 500, 500], nlv = Any["0:20", "0:20", "0:20", "0:20", "0:20", "0:20", "0:20", "0:20", "0:20", "0:20"  …  "5:30", "5:30", "5:30", "5:30", "5:30", "5:30", "5:30", "5:30", "5:30", "5:30"])

# %%
length(pars[1])
# Out:
# 72

# %%
res = gridscore(Xcal, ycal, Xval, yval;
    score = rmsep, fun = lwplsravg, pars = pars,
    verbose = false)
# Out:
# 72×6 DataFrame
#  Row │ nlvdis  metric  h    k    nlv   y1
#      │ Any     Any     Any  Any  Any   Float64
# ─────┼──────────────────────────────────────────
#    1 │ 15      mahal   1.0  200  0:20  0.723654
#    2 │ 25      mahal   1.0  200  0:20  0.787282
#    3 │ 15      mahal   2.5  200  0:20  0.773687
#    4 │ 25      mahal   2.5  200  0:20  0.804847
#    5 │ 15      mahal   5.0  200  0:20  0.818713
#    6 │ 25      mahal   5.0  200  0:20  0.852713
#    7 │ 15      mahal   1.0  350  0:20  0.740787
#    8 │ 25      mahal   1.0  350  0:20  0.836337
#   ⋮  │   ⋮       ⋮      ⋮    ⋮    ⋮       ⋮
#   66 │ 25      mahal   5.0  350  5:30  0.838063
#   67 │ 15      mahal   1.0  500  5:30  0.775285
#   68 │ 25      mahal   1.0  500  5:30  0.847664
#   69 │ 15      mahal   2.5  500  5:30  0.814153
#   70 │ 25      mahal   2.5  500  5:30  0.820296
#   71 │ 15      mahal   5.0  500  5:30  0.847675
#   72 │ 25      mahal   5.0  500  5:30  0.856835
#                                  57 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlvdis  metric  h    k    nlv   y1
#      │ Any     Any     Any  Any  Any   Float64
# ─────┼─────────────────────────────────────────
#   19 │ 15      mahal   1.0  200  5:20  0.71738

# %%
fm = lwplsravg(Xtrain, ytrain; nlvdis = res.nlvdis[u],
    metric = res.metric[u], h = res.h[u], k = res.k[u],
    nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
# Out:
# rmsep(pred, ytest) = [0.6904522905015641;;]
# 1×1 Matrix{Float64}:
#  0.6904522905015641

# %%
plotxy(vec(pred), ytest; resolution = (500, 400),
    color = (:red, .5), bisect = true,
    xlabel = "Prediction", ylabel = "Observed (Test)").f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
