# %%
using JLD2, CairoMakie, FreqTables
using Jchemo, JchemoData

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/forages2.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot = nro(X)
# Out:
# 485

# %%
@head X
# Out:
# ... (485, 700)
# 3×700 DataFrame
#  Row │ 1100          1102          1104         1106         1108         1110 ⋯
#      │ Float64       Float64       Float64      Float64      Float64      Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.000231591  -0.000175945  -8.48176e-5  2.05217e-5   0.000110094  0.00 ⋯
#    2 │ -9.66352e-5   -3.30928e-5    5.64966e-5  0.000154135  0.000237725  0.00
#    3 │ -0.000131769  -7.8398e-5     7.92223e-7  8.90044e-5   0.000160022  0.00
#                                                              695 columns omitted

# %%
@head Y
# Out:
# ... (485, 4)
# 3×4 DataFrame
#  Row │ dm        ndf       typ             test
#      │ Float64?  Float64?  String          Int64
# ─────┼───────────────────────────────────────────
#    1 │    92.23   37.58    Legume forages      1
#    2 │    93.26   49.6462  Legume forages      0
#    3 │    92.9    63.2939  Forage trees        0

# %%
y = Y.typ
tab(y)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "Cereal and grass forages" => 160
#   "Forage trees"             => 101
#   "Legume forages"           => 224

# %%
freqtable(y, Y.test)
# Out:
# 3×2 Named Matrix{Int64}
#              Dim1 ╲ Dim2 │   0    1
# ─────────────────────────┼─────────
# Cereal and grass forages │ 100   60
# Forage trees             │  56   45
# Legume forages           │ 167   57

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 700-element Vector{Float64}:
#  1100.0
#  1102.0
#  1104.0
#  1106.0
#  1108.0
#  1110.0
#  1112.0
#  1114.0
#  1116.0
#  1118.0
#     ⋮
#  2482.0
#  2484.0
#  2486.0
#  2488.0
#  2490.0
#  2492.0
#  2494.0
#  2496.0
#  2498.0

# %%
# X is already preprocessed
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = Bool.(Y.test)
Xtrain = rmrow(X, s)
ytrain = rmrow(y, s)
Xtest = X[s, :]
ytest = y[s]
ntrain = nro(Xtrain)
ntest = nro(Xtest)
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 485, ntrain = 323, ntest = 162)

# %%
gamma = .001
fm = kplsrda(Xtrain, ytrain; nlv = 15,
    gamma = gamma, scal = true) ;
pnames(fm)
# Out:
# (:fm, :lev, :ni)

# %%
pnames(fm.fm)
# Out:
# (:X, :Kt, :T, :C, :U, :R, :D, :DKt, :vtot, :xscales, :ymeans, :yscales, :weights, :kern, :dots, :iter)

# %%
typeof(fm.fm)
# Out:
# Jchemo.Kplsr

# %%
res = Jchemo.predict(fm, Xtest)
pnames(res)
# Out:
# (:pred, :posterior)

# %%
pred = res.pred
# Out:
# 162×1 Matrix{String}:
#  "Legume forages"
#  "Cereal and grass forages"
#  "Cereal and grass forages"
#  "Forage trees"
#  "Cereal and grass forages"
#  "Cereal and grass forages"
#  "Legume forages"
#  "Forage trees"
#  "Forage trees"
#  "Forage trees"
#  ⋮
#  "Cereal and grass forages"
#  "Cereal and grass forages"
#  "Forage trees"
#  "Forage trees"
#  "Legume forages"
#  "Legume forages"
#  "Legume forages"
#  "Legume forages"
#  "Legume forages"

# %%
res.posterior
# Out:
# 162×3 Matrix{Float64}:
#  -0.0213897  -0.106075     1.12746
#   0.998448   -0.0342315    0.0357834
#   0.958405   -0.0329318    0.0745269
#   0.048005    0.522485     0.42951
#   1.00485     0.00922003  -0.0140664
#   1.00559     0.0046622   -0.0102518
#   0.049684    0.0108771    0.939439
#   0.0611096   0.586556     0.352335
#  -0.0419387   0.935074     0.106865
#   0.121923    0.646258     0.231819
#   ⋮
#   0.596027   -0.0173082    0.421281
#   0.804895   -0.110898     0.306003
#   0.103326    0.912926    -0.0162526
#  -0.0307702   0.972875     0.0578947
#   0.422951    0.136409     0.44064
#   0.0182986   0.00999367   0.971708
#   0.0356912  -0.0509272    1.01524
#   0.289871    0.0958141    0.614315
#   0.0476274   0.0534935    0.898879

# %%
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.06172839506172839

# %%
cf = confusion(pred, ytest) ;
cf.cnt
# Out:
# 3×4 DataFrame
#  Row │ y                         pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Int64                          Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                             56                 ⋯
#    2 │ Forage trees                                          0
#    3 │ Legume forages                                        1
#                                                                2 columns omitted

# %%
cf.pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           93.3                 ⋯
#    2 │ Forage trees                                        0.0               8
#    3 │ Legume forages                                      1.8
#                                                                2 columns omitted

# %%
plotconf(cf).f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
