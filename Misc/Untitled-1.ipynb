# %%
using CairoMakie 
1 + 1
# Out:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# 2

# %% [markdown]
# ## Titre : Essai

# %%
z = rand(220)
hist(z; bins = 50)

# %% [markdown]
# blbla

# %% [markdown]
# gggg

# %%
3 + 5
# Out:
# 8
