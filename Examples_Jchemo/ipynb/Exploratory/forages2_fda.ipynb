# %%
using JLD2, CairoMakie, FreqTables
using Jchemo, JchemoData

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/forages2.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot = nro(X)
# Out:
# 485

# %%
@head X
# Out:
# ... (485, 700)
# 3×700 DataFrame
#  Row │ 1100          1102          1104         1106         1108         1110 ⋯
#      │ Float64       Float64       Float64      Float64      Float64      Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.000231591  -0.000175945  -8.48176e-5  2.05217e-5   0.000110094  0.00 ⋯
#    2 │ -9.66352e-5   -3.30928e-5    5.64966e-5  0.000154135  0.000237725  0.00
#    3 │ -0.000131769  -7.8398e-5     7.92223e-7  8.90044e-5   0.000160022  0.00
#                                                              695 columns omitted

# %%
@head Y
# Out:
# ... (485, 4)
# 3×4 DataFrame
#  Row │ dm        ndf       typ             test
#      │ Float64?  Float64?  String          Int64
# ─────┼───────────────────────────────────────────
#    1 │    92.23   37.58    Legume forages      1
#    2 │    93.26   49.6462  Legume forages      0
#    3 │    92.9    63.2939  Forage trees        0

# %%
y = Y.typ
tab(y)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "Cereal and grass forages" => 160
#   "Forage trees"             => 101
#   "Legume forages"           => 224

# %%
freqtable(y, Y.test)
# Out:
# 3×2 Named Matrix{Int64}
#              Dim1 ╲ Dim2 │   0    1
# ─────────────────────────┼─────────
# Cereal and grass forages │ 100   60
# Forage trees             │  56   45
# Legume forages           │ 167   57

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 700-element Vector{Float64}:
#  1100.0
#  1102.0
#  1104.0
#  1106.0
#  1108.0
#  1110.0
#  1112.0
#  1114.0
#  1116.0
#  1118.0
#     ⋮
#  2482.0
#  2484.0
#  2486.0
#  2488.0
#  2490.0
#  2492.0
#  2494.0
#  2496.0
#  2498.0

# %%
# X is already preprocessed
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
# Tot ==> Train + Test
s = Bool.(Y.test)
Xtrain = rmrow(X, s)
ytrain = rmrow(y, s)
Xtest = X[s, :]
ytest = y[s]
ntrain = nro(Xtrain)
ntest = nro(Xtest)
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 485, ntrain = 323, ntest = 162)

# %%
# X contains high multicolinearities
# ==> a regularization is required for the FDA,
# for instance:
# 1) by preliminary dimension reduction
# 2) or using a ridge regularization

# 1) FDA on PCA scores
fm0 = pcasvd(Xtrain; nlv = 10) ;
pnames(fm0)
# Out:
# (:T, :P, :sv, :xmeans, :xscales, :weights, :niter)

# %%
Ttrain_pca = fm0.T
# Out:
# 323×10 Matrix{Float64}:
#  -0.00669306  -0.00650046   -0.00570717   …  -0.000492699   0.000134327
#  -0.00387969  -0.0068879    -0.00728328       0.0003361    -0.000581481
#   0.0022825    0.00305238    0.00109557      -0.00164726   -0.0014889
#  -0.00270136   0.00250878    0.00219682       0.00142804    0.00235234
#  -0.00491993  -0.0112622    -0.00319506       0.000697076   0.000562345
#   0.00852042   0.00214753   -0.00215239   …  -0.00214551   -0.000785859
#   0.00698183   0.00555323   -0.00113576      -0.00115834   -0.00164311
#   0.00768161   0.00415699   -0.000872215     -0.00171996   -0.00128135
#   0.00299812   6.36903e-5    0.000181228     -0.00410388   -0.00153194
#   0.00156368   0.00227962   -0.000141488     -0.00142395   -0.00111151
#   ⋮                                       ⋱
#  -0.00157233  -0.00504454    0.000368828     -0.00110731   -0.000456322
#  -0.00192579  -0.00598648   -0.000865345  …  -0.000285707  -0.000207158
#  -0.00132785  -0.00413562    0.000617733     -0.00117947   -8.67228e-5
#  -0.0002287   -0.00355393    0.000604328     -0.000895126  -0.00018348
#  -0.00514553   0.00293335    0.00406394       0.00171186    0.00114643
#  -0.00301654   0.00394264    0.00391489       0.00051332   -0.000481935
#   0.0126632   -0.001239     -0.00278504   …   0.0021392    -0.00214385
#   0.00687631   0.000352933   0.0018552        0.00228765   -0.00257893
#   0.00217267   0.00222082    0.00278309       0.00169606    4.42911e-5

# %%
fm = fda(Ttrain_pca, ytrain; nlv = 2) ;
#fm = fdasvd(Ttrain_pca, ytrain; nlv = 2) ;
pnames(fm)
# Out:
# (:T, :P, :Tcenters, :eig, :sstot, :W, :xmeans, :xscales, :lev, :ni)

# %%
Ttrain = fm.T
# Out:
# 323×2 Matrix{Float64}:
#   2.46522    1.88438
#   1.25316    1.62238
#  -2.20229    0.428528
#   3.43676   -0.835856
#   2.14512    5.04708
#  -4.08316    0.742762
#  -3.43614    0.618855
#  -3.3355    -0.122161
#  -3.37633    1.26948
#  -2.65985    0.874371
#   ⋮
#   1.01288    2.81331
#   1.14919    2.88673
#   0.764002   1.90987
#   0.739069   2.1485
#   2.08194   -2.12382
#   1.53105   -1.35389
#  -2.61568   -0.355692
#  -0.526769  -1.7154
#   0.660274  -2.39033

# %%
lev = fm.lev
nlev = length(lev)
# Out:
# 3

# %%
plotxy(Ttrain[:, 1:2], ytrain;
    resolution = (800, 400), ellipse = true,
    title = "FDA").f
# Out:
# Figure()

# %%
# 2) FDA directly on X
# ==> using ridge regularization
# Rq: If lb is too small (e.g. here 1e-10)
# the model can overfit the discrimination of new observations
lb = 1e-5
fm = fda(Xtrain, ytrain; nlv = 2, lb = lb) ;
#fm = fdasvd(Xtrain, ytrain; nlv = 2, lb = lb) ;
pnames(fm)
# Out:
# (:T, :P, :Tcenters, :eig, :sstot, :W, :xmeans, :xscales, :lev, :ni)

# %%
lev = fm.lev
nlev = length(lev)
# Out:
# 3

# %%
ct = fm.Tcenters
# Out:
# 3×2 Matrix{Float64}:
#  -1.32132    0.258153
#   1.28728    0.835213
#   0.359546  -0.434654

# %%
Ttrain = fm.T
# Out:
# 323×2 Matrix{Float64}:
#   1.78298    0.892334
#   1.32039    1.08711
#  -0.881565   0.00540248
#   0.663423  -0.577376
#   2.47163    1.94774
#  -1.73198    0.61924
#  -1.72178    0.467534
#  -1.74633    0.117357
#  -0.86571    0.259558
#  -0.84413    0.329829
#   ⋮
#   1.27624    0.89071
#   1.39446    1.07433
#   0.956269   0.582905
#   0.872945   0.685624
#   0.311586  -1.1357
#   0.103525  -0.821741
#  -1.34809    0.497461
#  -0.704278  -0.52345
#  -0.46311   -1.04653

# %%
f, ax = plotxy(Ttrain[:, 1:2], ytrain;
    title = "FDA", ellipse = true)
scatter!(ax, ct[:, 1], ct[:, 2],
    markersize = 10, color = :red)
f
# Out:
# Figure()

# %%
# Test
Ttest = Jchemo.transform(fm, Xtest)
# Out:
# 162×2 Matrix{Float64}:
#   1.47243    -0.224802
#  -1.39627     0.2853
#  -0.995825    0.334509
#   1.30237    -0.225391
#  -1.83457     0.0140786
#  -1.86595     0.876474
#   1.12847     0.402805
#   1.23208     0.507262
#   2.07156     1.85664
#   1.065       0.247035
#   ⋮
#  -0.988968   -0.475229
#  -1.51727     0.417494
#   1.01014     0.921027
#   1.30524     1.05689
#  -0.593537   -0.00818024
#   0.0596587  -0.769732
#   0.370658   -1.16058
#  -1.27663    -0.206246
#  -0.789946   -0.67317

# %%
i = 1  # class
f, ax = plotxy(Ttrain[:, 1:2], ytrain;
    title = "FDA")
scatter!(ax, ct[:, 1], ct[:, 2],
    markersize = 10, color = :red)
s = ytest .== lev[i]
zT = Ttest[s, :]
scatter!(ax, zT[:, 1], zT[:, 2],
    markersize = 10, color = (:purple, .8))
f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
