# %%
using JLD2, CairoMakie, GLMakie
using Jchemo, JchemoData
CairoMakie.activate!()

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/octane.jld2")
@load db dat
pnames(dat)
# Out:
# (:X,)

# %%
X = dat.X
n = nro(X)
# Out:
# 39

# %%
@head X
# Out:
# ... (39, 226)
# 3×226 DataFrame
#  Row │ 1102         1104         1106         1108         1110        1112    ⋯
#      │ Float64      Float64      Float64      Float64      Float64     Float64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.0018345   -0.0014965   -0.0010088   -0.00036036  0.00046595  0.00150 ⋯
#    2 │ -0.001627    -0.0012608   -0.00074818  -6.5377e-5   0.00081759  0.00194
#    3 │ -0.00046487  -0.00033003   0.00018072   0.0011213   0.0024647   0.00413
#                                                              221 columns omitted

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 226-element Vector{Float64}:
#  1102.0
#  1104.0
#  1106.0
#  1108.0
#  1110.0
#  1112.0
#  1114.0
#  1116.0
#  1118.0
#  1120.0
#     ⋮
#  1536.0
#  1538.0
#  1540.0
#  1542.0
#  1544.0
#  1546.0
#  1548.0
#  1550.0
#  1552.0

# %%
# Six of the samples of the dataset contain
# added alcohol  (= 25, 26, and 36-39)
plotsp(X, wl_num;
    xlabel ="Wavelength (nm)", ylabel = "Absorbance",
    title = "Octane data").f
# Out:
# Figure()

# %%
# Model fitting
fm = pcasvd(X; nlv = 6) ;
# For robust PCA:
#fm = pcasph(X; nlv = 6) ;
pnames(fm)
# Out:
# (:T, :P, :sv, :xmeans, :xscales, :weights, :niter)

# %%
# Summary of the fitted model
res = summary(fm, X) ;
pnames(res)
# Out:
# (:explvarx, :contr_ind, :contr_var, :coord_var, :cor_circle)

# %%
# % Variance explained
z = res.explvarx
# Out:
# 6×4 DataFrame
#  Row │ lv     var          pvar         cumpvar
#      │ Int64  Float64      Float64      Float64
# ─────┼───────────────────────────────────────────
#    1 │     1  0.129243     0.922872     0.922872
#    2 │     2  0.0085218    0.0608505    0.983722
#    3 │     3  0.0013271    0.00947622   0.993199
#    4 │     4  0.000725132  0.00517786   0.998377
#    5 │     5  0.000106008  0.000756957  0.999133
#    6 │     6  4.76697e-5   0.000340389  0.999474

# %%
plotgrid(z.lv, 100 * z.pvar; step = 1,
    xlabel = "nb. PCs", ylabel = "% variance explained").f
# Out:
# Figure()

# %%
# Individuals' contributions to scores
z = res.contr_ind
# Out:
# 39×6 DataFrame
#  Row │ lv1         lv2          lv3          lv4          lv5          lv6     ⋯
#      │ Float64     Float64      Float64      Float64      Float64      Float64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 0.00413674  0.00353011   0.000901052  0.00141409   0.0584335    0.04414 ⋯
#    2 │ 0.00324611  0.0123323    0.00389918   0.000589509  0.0073111    0.02052
#    3 │ 0.00255591  0.00213627   0.00690889   0.00869044   0.0637687    0.09676
#    4 │ 0.00181259  0.0413868    0.0126569    0.00220926   0.0221098    9.73252
#    5 │ 0.0067063   0.0334915    1.07146e-5   0.00321373   0.00037921   0.00850 ⋯
#    6 │ 0.00896334  0.0655935    0.0360542    0.000875733  0.0739264    0.01403
#    7 │ 0.00582111  0.000158061  0.0710544    7.81857e-5   0.0175937    0.00795
#    8 │ 0.00293237  0.0492891    0.00416645   0.000378776  0.0236706    0.02652
#   ⋮  │     ⋮            ⋮            ⋮            ⋮            ⋮           ⋮   ⋱
#   33 │ 0.00436922  0.000127457  0.0241624    0.000124498  0.0189799    0.00116 ⋯
#   34 │ 0.0108991   0.0984106    0.0844327    0.00557485   0.0232381    0.02709
#   35 │ 0.00163505  0.0665265    6.97652e-7   0.00260953   0.0907003    0.04920
#   36 │ 0.102812    0.00477685   0.0106718    0.0745562    0.00853881   0.00471
#   37 │ 0.102806    0.000820436  4.95855e-5   0.052026     0.031915     0.00822 ⋯
#   38 │ 0.161227    0.00200685   0.000167377  0.00166585   0.00921291   0.00865
#   39 │ 0.1132      0.000618775  0.000320394  0.054999     0.00259743   0.00102
#                                                     1 column and 24 rows omitted

# %%
i = 1
scatter(z[:, i];
    axis = (xlabel = "Observation", ylabel = "Contribution",
        title = string("PC", i)))
# Out:
# FigureAxisPlot()

# %%
# Same:
plotxy(1:n, z[:, i];
    xlabel = "Observation", ylabel = "Contribution",
    title = string("PC", i)).f
# Out:
# Figure()

# %%
# Variables' contributions
z = res.contr_var
# Out:
# 226×6 DataFrame
#  Row │ lv1         lv2          lv3         lv4         lv5          lv6       ⋯
#      │ Float64     Float64      Float64     Float64     Float64      Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 7.34715e-6  1.28131e-6   1.40569e-6  5.98007e-5  0.00101684   0.0005170 ⋯
#    2 │ 7.38595e-6  4.61408e-7   1.2328e-6   5.6046e-5   0.00110175   0.0004010
#    3 │ 7.46459e-6  3.71513e-8   1.11688e-6  5.33991e-5  0.00126521   0.0003536
#    4 │ 7.59447e-6  1.13576e-7   1.03658e-6  5.19471e-5  0.00156626   0.0003480
#    5 │ 7.77411e-6  8.66776e-7   9.265e-7    5.10737e-5  0.00206293   0.0003449 ⋯
#    6 │ 8.00064e-6  2.67011e-6   7.11495e-7  4.95933e-5  0.00280325   0.0003048
#    7 │ 8.27687e-6  6.35273e-6   3.38336e-7  4.59784e-5  0.0037886    0.0002167
#    8 │ 8.62266e-6  1.36061e-5   8.34041e-9  3.96277e-5  0.0049511    0.0001156
#   ⋮  │     ⋮            ⋮           ⋮           ⋮            ⋮            ⋮    ⋱
#  220 │ 0.017099    0.00109927   0.00253253  0.00388264  0.000419981  0.0004128 ⋯
#  221 │ 0.0172401   0.00118858   0.00248067  0.00400236  0.000437305  0.0005337
#  222 │ 0.0173574   0.00128262   0.00240518  0.00416948  0.000451546  0.0006130
#  223 │ 0.0174569   0.00138078   0.00231298  0.00438962  0.000461703  0.0006135
#  224 │ 0.0175459   0.0014809    0.00221267  0.00465951  0.000464387  0.0005294 ⋯
#  225 │ 0.0176337   0.00158022   0.00210934  0.00494377  0.000463954  0.0003876
#  226 │ 0.0177304   0.00167646   0.00201     0.00523934  0.000456515  0.0002363
#                                                    1 column and 211 rows omitted

# %%
i = 1
scatter(z[:, i], z[:, i + 1])
# Out:
# FigureAxisPlot()

# %%
# Correlation circle
z = res.cor_circle
# Out:
# 226×6 DataFrame
#  Row │ lv1        lv2         lv3          lv4         lv5          lv6        ⋯
#      │ Float64    Float64     Float64      Float64     Float64      Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.831523  -0.0891669   0.0368559   -0.177694    0.280161    -0.133963  ⋯
#    2 │ -0.837058  -0.0537225   0.0346534   -0.172714    0.292792    -0.118464
#    3 │ -0.839057  -0.0151998   0.0328881   -0.168097    0.31285     -0.110922
#    4 │ -0.836484   0.0262671   0.0313154   -0.163868    0.344038    -0.108757
#    5 │ -0.82658    0.0708719   0.0289154   -0.158695    0.385626    -0.10574   ⋯
#    6 │ -0.807538   0.119792    0.0244025   -0.150597    0.432909    -0.0957262
#    7 │ -0.780899   0.175672    0.0159986   -0.137862    0.478483    -0.0767445
#    8 │ -0.749837   0.241866    0.00236313  -0.120407    0.514591    -0.0527298
#   ⋮  │     ⋮          ⋮            ⋮           ⋮            ⋮            ⋮     ⋱
#  220 │  0.996438   0.0648752  -0.0388588   -0.0355659  -0.00447244  -0.0029735 ⋯
#  221 │  0.99629    0.0671724  -0.0382954   -0.0359565  -0.00454435  -0.0033665
#  222 │  0.996132   0.0695321  -0.0375747   -0.0365696  -0.0046014   -0.0035952
#  223 │  0.995965   0.0719256  -0.0367361   -0.0374091  -0.00463881  -0.0035858
#  224 │  0.99579    0.0742853  -0.0358331   -0.0384374  -0.00463964  -0.0033219 ⋯
#  225 │  0.995617   0.0765316  -0.0348932   -0.039487   -0.00462512  -0.0028349
#  226 │  0.99545    0.0785991  -0.0339629   -0.0405324  -0.00457459  -0.0022070
#                                                    1 column and 211 rows omitted

# %%
i = 1
plotxy(z[:, i:(i + 1)]; resolution = (400, 400),
    circle = true, zeros = true,
    xlabel = string("PC", i),
    ylabel = string("PC", i + 1)).f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
