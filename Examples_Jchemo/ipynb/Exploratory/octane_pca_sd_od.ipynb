# %%
using JLD2, CairoMakie, GLMakie
using Jchemo, JchemoData
CairoMakie.activate!()

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/octane.jld2")
@load db dat
pnames(dat)
# Out:
# (:X,)

# %%
X = dat.X
n = nro(X)
# Out:
# 39

# %%
@head X
# Out:
# ... (39, 226)
# 3×226 DataFrame
#  Row │ 1102         1104         1106         1108         1110        1112    ⋯
#      │ Float64      Float64      Float64      Float64      Float64     Float64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.0018345   -0.0014965   -0.0010088   -0.00036036  0.00046595  0.00150 ⋯
#    2 │ -0.001627    -0.0012608   -0.00074818  -6.5377e-5   0.00081759  0.00194
#    3 │ -0.00046487  -0.00033003   0.00018072   0.0011213   0.0024647   0.00413
#                                                              221 columns omitted

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 226-element Vector{Float64}:
#  1102.0
#  1104.0
#  1106.0
#  1108.0
#  1110.0
#  1112.0
#  1114.0
#  1116.0
#  1118.0
#  1120.0
#     ⋮
#  1536.0
#  1538.0
#  1540.0
#  1542.0
#  1544.0
#  1546.0
#  1548.0
#  1550.0
#  1552.0

# %%
# Six of the samples of the dataset contain
# added alcohol  (= 25, 26, and 36-39)
plotsp(X, wl_num;
    xlabel ="Wavelength (nm)", ylabel = "Absorbance",
    title = "Octane data").f
# Out:
# Figure()

# %%
# Model fitting
fm = pcasvd(X; nlv = 6) ;
# For robust PCA:
#fm = pcasph(X; nlv = 6) ;
pnames(fm)
# Out:
# (:T, :P, :sv, :xmeans, :xscales, :weights, :niter)

# %%
# Score distance (SD)
res = occsd(fm) ;
pnames(res)
# Out:
# (:d, :fm, :Sinv, :e_cdf, :cutoff, :nlv)

# %%
d = res.d
# Out:
# 39×4 DataFrame
#  Row │ d        dstand    pval       gh
#      │ Float64  Float64   Float64    Float64
# ─────┼────────────────────────────────────────
#    1 │ 2.09516  0.479019  0.538462   0.731616
#    2 │ 1.36684  0.312503  0.923077   0.311377
#    3 │ 2.65561  0.607154  0.307692   1.17537
#    4 │ 1.76936  0.40453   0.769231   0.521772
#    5 │ 1.42829  0.326552  0.846154   0.340002
#    6 │ 2.78897  0.637645  0.205128   1.29639
#    7 │ 2.00096  0.457482  0.615385   0.667308
#    8 │ 2.04246  0.46697   0.589744   0.695275
#   ⋮  │    ⋮        ⋮          ⋮         ⋮
#   33 │ 1.38142  0.315836  0.897436   0.318054
#   34 │ 3.12031  0.7134    0.0512821  1.62272
#   35 │ 2.8664   0.655347  0.102564   1.36937
#   36 │ 2.8349   0.648146  0.153846   1.33944
#   37 │ 2.76369  0.631865  0.230769   1.27299
#   38 │ 2.67103  0.610681  0.282051   1.18907
#   39 │ 2.59571  0.59346   0.358974   1.12295
#                                24 rows omitted

# %%
f = Figure(resolution = (500, 400))
Axis(f[1, 1]; xlabel = "Standardized score distance",
    ylabel = "Nb. observations")
hist!(d.dstand; bins = 20)
f
# Out:
# Figure()

# %%
# Orthogonal distance (OD)
res = occod(fm, X) ;
pnames(res)
# Out:
# (:d, :fm, :e_cdf, :cutoff, :nlv)

# %%
d = res.d
# Out:
# 39×3 DataFrame
#  Row │ d           dstand    pval
#      │ Float64     Float64   Float64
# ─────┼────────────────────────────────
#    1 │ 0.00428182  0.256255  0.820513
#    2 │ 0.00829593  0.496489  0.410256
#    3 │ 0.0169662   1.01538   0.0
#    4 │ 0.00840665  0.503115  0.358974
#    5 │ 0.0108795   0.65111   0.102564
#    6 │ 0.00719981  0.430889  0.589744
#    7 │ 0.0164864   0.986664  0.025641
#    8 │ 0.0081667   0.488755  0.487179
#   ⋮  │     ⋮          ⋮         ⋮
#   33 │ 0.00420747  0.251805  0.846154
#   34 │ 0.0071367   0.427112  0.615385
#   35 │ 0.0101053   0.604776  0.179487
#   36 │ 0.010442    0.624925  0.128205
#   37 │ 0.00959707  0.574359  0.282051
#   38 │ 0.00246275  0.147389  0.948718
#   39 │ 0.00561125  0.335818  0.74359
#                        24 rows omitted

# %%
f = Figure(resolution = (500, 400))
Axis(f[1, 1]; xlabel = "Standardized orthogonal distance",
    ylabel = "Nb. observations")
hist!(d.dstand; bins = 20)
f
# Out:
# Figure()

# %%
# SD-OD
sd = occsd(fm).d
od = occod(fm, X).d
f, ax = plotxy(sd.dstand, od.dstand;
    xlabel = "Standardized SD", ylabel = "Standardized OD")
hlines!(ax, 1)
vlines!(ax, 1)
f
# Out:
# Figure()

# %%
CairoMakie.activate!()
#GLMakie.activate!()
sd = occsd(fm).d
od = occod(fm, X).d
f, ax = plotxy(sd.dstand, od.dstand;
    xlabel = "Standardized SD", ylabel = "Standardized OD")
text!(ax, sd.dstand, od.dstand; text = string.(1:n),
    fontsize = 15)
hlines!(ax, 1)
vlines!(ax, 1)
f
# Out:
# Figure()

# %%
# Direct computation of a composite SD-OD
res = occsdod(fm, X) ;
pnames(res)
# Out:
# (:d, :fm_sd, :fm_od)

# %%
d = res.d
# Out:
# 39×8 DataFrame
#  Row │ d_sd     dstand_sd  pval_sd    gh_sd     d_od        dstand_od  pval_od ⋯
#      │ Float64  Float64    Float64    Float64   Float64     Float64    Float64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2.09516   0.479019  0.538462   0.731616  0.00428182   0.256255  0.82051 ⋯
#    2 │ 1.36684   0.312503  0.923077   0.311377  0.00829593   0.496489  0.41025
#    3 │ 2.65561   0.607154  0.307692   1.17537   0.0169662    1.01538   0.0
#    4 │ 1.76936   0.40453   0.769231   0.521772  0.00840665   0.503115  0.35897
#    5 │ 1.42829   0.326552  0.846154   0.340002  0.0108795    0.65111   0.10256 ⋯
#    6 │ 2.78897   0.637645  0.205128   1.29639   0.00719981   0.430889  0.58974
#    7 │ 2.00096   0.457482  0.615385   0.667308  0.0164864    0.986664  0.02564
#    8 │ 2.04246   0.46697   0.589744   0.695275  0.0081667    0.488755  0.48717
#   ⋮  │    ⋮         ⋮          ⋮         ⋮          ⋮           ⋮         ⋮    ⋱
#   33 │ 1.38142   0.315836  0.897436   0.318054  0.00420747   0.251805  0.84615 ⋯
#   34 │ 3.12031   0.7134    0.0512821  1.62272   0.0071367    0.427112  0.61538
#   35 │ 2.8664    0.655347  0.102564   1.36937   0.0101053    0.604776  0.17948
#   36 │ 2.8349    0.648146  0.153846   1.33944   0.010442     0.624925  0.12820
#   37 │ 2.76369   0.631865  0.230769   1.27299   0.00959707   0.574359  0.28205 ⋯
#   38 │ 2.67103   0.610681  0.282051   1.18907   0.00246275   0.147389  0.94871
#   39 │ 2.59571   0.59346   0.358974   1.12295   0.00561125   0.335818  0.74359
#                                                    2 columns and 24 rows omitted

# %%
f, ax = plotxy(1:n, d.dstand;
    xlabel = "Observation",
    ylabel = "Standardized SD-OD distance")
text!(ax, 1:n, d.dstand; text = string.(1:n),
    fontsize = 15)
hlines!(ax, 1)
f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
