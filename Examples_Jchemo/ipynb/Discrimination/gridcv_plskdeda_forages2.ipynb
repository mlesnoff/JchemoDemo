#  [[1, 3, 4, 5, 7, 10, 13, 15, 18, 21  …  287, 290, 292, 295, 302, 308, 309, 314, 316, 323], [9, 14, 16, 20, 24, 29, 30, 31, 33, 35  …  301, 303, 305, 312, 313, 315, 317, 319, 320, 321], [2, 6, 8, 11, 12, 17, 19, 22, 26, 32  …  281, 284, 293, 304, 306, 307, 310, 311, 318, 322]]
#  [[3, 4, 5, 8, 9, 11, 14, 16, 18, 22  …  295, 296, 297, 298, 305, 306, 310, 311, 313, 321], [1, 6, 7, 10, 15, 17, 19, 21, 24, 28  …  294, 299, 303, 309, 312, 315, 316, 318, 319, 320], [2, 12, 13, 20, 23, 25, 26, 27, 29, 32  …  300, 301, 302, 304, 307, 308, 314, 317, 322, 323]]

# %%
# PLS-LDA
nlv = 1:50
rescv = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plslda, nlv = nlv) ;
res = rescv.res
# Out:
# 50×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#    1 │     1  0.271792
#    2 │     2  0.219788
#    3 │     3  0.206464
#    4 │     4  0.152608
#    5 │     5  0.139004
#    6 │     6  0.125692
#    7 │     7  0.120428
#    8 │     8  0.120128
#   ⋮  │   ⋮        ⋮
#   44 │    44  0.104035
#   45 │    45  0.104656
#   46 │    46  0.108065
#   47 │    47  0.108388
#   48 │    48  0.690418
#   49 │    49  0.690418
#   50 │    50  0.690418
#          35 rows omitted

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "Err-CV").f
# Out:
# Figure()

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#   42 │    42  0.0993856

# %%
fm = plslda(Xtrain, ytrain; nlv = res.nlv[u]) ;
res = Jchemo.predict(fm, Xtest) ;
pred = res.pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.1111111111111111

# %%
confusion(pred, ytest).pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           90.0                 ⋯
#    2 │ Forage trees                                        0.0               7
#    3 │ Legume forages                                      0.0
#                                                                2 columns omitted

# %%
# PLS-KDE-DA
pars = mpar(a = [.5, 1, 1.5])
# Out:
# (a = [0.5, 1.0, 1.5],)

# %%
nlv = 1:50
rescv = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plskdeda, pars = pars, nlv = nlv) ;
res = rescv.res
# Out:
# 150×3 DataFrame
#  Row │ nlv    a        y1
#      │ Int64  Float64  Float64
# ─────┼──────────────────────────
#    1 │     1      0.5  0.293161
#    2 │     2      0.5  0.232197
#    3 │     3      0.5  0.217353
#    4 │     4      0.5  0.175228
#    5 │     5      0.5  0.147964
#    6 │     6      0.5  0.134663
#    7 │     7      0.5  0.125063
#    8 │     8      0.5  0.123514
#   ⋮  │   ⋮       ⋮        ⋮
#  144 │    44      1.5  0.178943
#  145 │    45      1.5  0.178017
#  146 │    46      1.5  0.176168
#  147 │    47      1.5  0.178652
#  148 │    48      1.5  0.180201
#  149 │    49      1.5  0.18113
#  150 │    50      1.5  0.17896
#                 135 rows omitted

# %%
group = string.("a = ", res.a)
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel = "Nb. LVs", ylabel = "Err-CV").f
# Out:
# Figure()

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    a        y1
#      │ Int64  Float64  Float64
# ─────┼───────────────────────────
#   67 │    17      1.0  0.0860794

# %%
fm = plskdeda(Xtrain, ytrain; nlv = res.nlv[u],
    a = res.a[u]) ;
res = Jchemo.predict(fm, Xtest) ;
pred = res.pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.06790123456790123

# %%
confusion(pred, ytest).pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           96.7                 ⋯
#    2 │ Forage trees                                        0.0               9
#    3 │ Legume forages                                      3.5
#                                                                2 columns omitted

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
