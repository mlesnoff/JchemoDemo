#  [[1, 2, 3, 4, 13, 18, 19, 21, 22, 27  …  300, 302, 307, 308, 310, 313, 316, 317, 318, 321], [5, 7, 8, 12, 14, 16, 23, 24, 25, 30  …  292, 301, 303, 305, 306, 312, 314, 315, 319, 323], [6, 9, 10, 11, 15, 17, 20, 26, 28, 29  …  280, 284, 291, 293, 296, 304, 309, 311, 320, 322]]
#  [[3, 5, 8, 16, 17, 18, 19, 24, 29, 30  …  305, 307, 308, 312, 313, 317, 318, 320, 322, 323], [9, 13, 15, 20, 22, 23, 25, 34, 40, 43  …  298, 299, 301, 302, 304, 309, 310, 311, 319, 321], [1, 2, 4, 6, 7, 10, 11, 12, 14, 21  …  282, 285, 292, 295, 296, 300, 306, 314, 315, 316]]
#  [[2, 6, 9, 13, 14, 16, 18, 21, 24, 25  …  296, 299, 300, 306, 307, 311, 313, 314, 322, 323], [1, 3, 4, 10, 11, 12, 15, 22, 23, 27  …  294, 297, 298, 303, 305, 308, 309, 316, 320, 321], [5, 7, 8, 17, 19, 20, 32, 34, 35, 38  …  290, 301, 302, 304, 310, 312, 315, 317, 318, 319]]

# %%
nlv = 0:50
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plsrda, nlv = nlv, verbose = false).res
# Out:
# 51×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#    1 │     0  0.483002
#    2 │     1  0.280772
#    3 │     2  0.227559
#    4 │     3  0.205284
#    5 │     4  0.135606
#    6 │     5  0.129428
#    7 │     6  0.124161
#    8 │     7  0.111777
#   ⋮  │   ⋮        ⋮
#   45 │    44  0.100903
#   46 │    45  0.102755
#   47 │    46  0.104918
#   48 │    47  0.105235
#   49 │    48  0.108648
#   50 │    49  0.113909
#   51 │    50  0.114218
#          36 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#   33 │    32  0.0925724

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = plsrda(Xtrain, ytrain; nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.08641975308641975

# %%
cf = confusion(pred, ytest) ;
cf.cnt
# Out:
# 3×4 DataFrame
#  Row │ y                         pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Int64                          Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                             54                 ⋯
#    2 │ Forage trees                                          0
#    3 │ Legume forages                                        0
#                                                                2 columns omitted

# %%
cf.pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           90.0                 ⋯
#    2 │ Forage trees                                        0.0               8
#    3 │ Legume forages                                      0.0
#                                                                2 columns omitted

# %%
plotconf(cf).f
# Out:
# Figure()

# %%
# PLSLDA
nlv = 1:50  ## !!: Does not start from nlv=0 (since LDA on scores)
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plslda, nlv = nlv, verbose = false).res
# Out:
# 50×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#    1 │     1  0.274288
#    2 │     2  0.212706
#    3 │     3  0.198774
#    4 │     4  0.141491
#    5 │     5  0.135635
#    6 │     6  0.117059
#    7 │     7  0.120151
#    8 │     8  0.116436
#   ⋮  │   ⋮        ⋮
#   44 │    44  0.103363
#   45 │    45  0.103978
#   46 │    46  0.10769
#   47 │    47  0.10707
#   48 │    48  0.690366
#   49 │    49  0.690366
#   50 │    50  0.690366
#          35 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#   29 │    29  0.0913263

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = plslda(Xtrain, ytrain; nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.08641975308641975

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
