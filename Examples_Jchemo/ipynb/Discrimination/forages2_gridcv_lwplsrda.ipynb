# %%
using JLD2, CairoMakie, FreqTables
using Jchemo, JchemoData

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/forages2.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot = nro(X)
# Out:
# 485

# %%
@head X
# Out:
# ... (485, 700)
# 3×700 DataFrame
#  Row │ 1100          1102          1104         1106         1108         1110 ⋯
#      │ Float64       Float64       Float64      Float64      Float64      Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.000231591  -0.000175945  -8.48176e-5  2.05217e-5   0.000110094  0.00 ⋯
#    2 │ -9.66352e-5   -3.30928e-5    5.64966e-5  0.000154135  0.000237725  0.00
#    3 │ -0.000131769  -7.8398e-5     7.92223e-7  8.90044e-5   0.000160022  0.00
#                                                              695 columns omitted

# %%
@head Y
# Out:
# ... (485, 4)
# 3×4 DataFrame
#  Row │ dm        ndf       typ             test
#      │ Float64?  Float64?  String          Int64
# ─────┼───────────────────────────────────────────
#    1 │    92.23   37.58    Legume forages      1
#    2 │    93.26   49.6462  Legume forages      0
#    3 │    92.9    63.2939  Forage trees        0

# %%
y = Y.typ
tab(y)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "Cereal and grass forages" => 160
#   "Forage trees"             => 101
#   "Legume forages"           => 224

# %%
freqtable(y, Y.test)
# Out:
# 3×2 Named Matrix{Int64}
#              Dim1 ╲ Dim2 │   0    1
# ─────────────────────────┼─────────
# Cereal and grass forages │ 100   60
# Forage trees             │  56   45
# Legume forages           │ 167   57

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 700-element Vector{Float64}:
#  1100.0
#  1102.0
#  1104.0
#  1106.0
#  1108.0
#  1110.0
#  1112.0
#  1114.0
#  1116.0
#  1118.0
#     ⋮
#  2482.0
#  2484.0
#  2486.0
#  2488.0
#  2490.0
#  2492.0
#  2494.0
#  2496.0
#  2498.0

# %%
# X is already preprocessed
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = Bool.(Y.test)
Xtrain = rmrow(X, s)
ytrain = rmrow(y, s)
Xtest = X[s, :]
ytest = y[s]
ntrain = nro(Xtrain)
ntest = nro(Xtest)
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 485, ntrain = 323, ntest = 162)

# %%
K = 3 ; segm = segmkf(ntrain, K; rep = 1)       # K-fold CV
#m = 100 ; segm = segmts(ntrain, m; rep = 3)    # Test-set CV
# Out:
# 1-element Vector{Any}:
#  [[5, 6, 10, 14, 16, 20, 21, 24, 27, 30  …  298, 300, 302, 305, 306, 307, 309, 314, 316, 319], [2, 3, 4, 7, 8, 9, 11, 12, 23, 25  …  303, 308, 310, 312, 313, 315, 318, 320, 321, 322], [1, 13, 15, 17, 18, 19, 22, 26, 29, 31  …  288, 290, 291, 294, 296, 297, 304, 311, 317, 323]]

# %%
nlvdis = [25] ; metric = ["mahal"]
h = [1; 2; 5] ; k = [100; 250; 500]
nlv = 0:15
pars = mpar(nlvdis = nlvdis, metric = metric, h = h,
    k = k)
# Out:
# (nlvdis = Any[25, 25, 25, 25, 25, 25, 25, 25, 25], metric = Any["mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"], h = Any[1, 2, 5, 1, 2, 5, 1, 2, 5], k = Any[100, 100, 100, 250, 250, 250, 500, 500, 500])

# %%
length(pars[1])
# Out:
# 9

# %%
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = lwplsrda, nlv = nlv, pars = pars,
    verbose = false).res
# Out:
# 144×6 DataFrame
#  Row │ nlv    nlvdis  metric  h    k    y1
#      │ Int64  Any     Any     Any  Any  Float64
# ─────┼────────────────────────────────────────────
#    1 │     0  25      mahal   1    100  0.148754
#    2 │     1  25      mahal   1    100  0.099025
#    3 │     2  25      mahal   1    100  0.0989385
#    4 │     3  25      mahal   1    100  0.0927945
#    5 │     4  25      mahal   1    100  0.0865928
#    6 │     5  25      mahal   1    100  0.08042
#    7 │     6  25      mahal   1    100  0.071103
#    8 │     7  25      mahal   1    100  0.0741895
#   ⋮  │   ⋮      ⋮       ⋮      ⋮    ⋮       ⋮
#  138 │     9  25      mahal   5    500  0.0960252
#  139 │    10  25      mahal   5    500  0.0960828
#  140 │    11  25      mahal   5    500  0.0898523
#  141 │    12  25      mahal   5    500  0.0929676
#  142 │    13  25      mahal   5    500  0.105313
#  143 │    14  25      mahal   5    500  0.105342
#  144 │    15  25      mahal   5    500  0.102227
#                                   129 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    nlvdis  metric  h    k    y1
#      │ Int64  Any     Any     Any  Any  Float64
# ─────┼───────────────────────────────────────────
#   27 │    10  25      mahal   2    100  0.058815

# %%
group = string.("metric=", res.metric, res.nlvdis, " h=", res.h, " k=", res.k)
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = lwplsrda(Xtrain, ytrain; nlvdis = res.nlvdis[u],
    metric = res.metric[u], h = res.h[u], k = res.k[u],
    nlv = res.nlv[u], verbose = false) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.08641975308641975

# %%
cf = confusion(pred, ytest) ;
cf.cnt
# Out:
# 3×4 DataFrame
#  Row │ y                         pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Int64                          Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                             57                 ⋯
#    2 │ Forage trees                                          0
#    3 │ Legume forages                                        5
#                                                                2 columns omitted

# %%
cf.pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           95.0                 ⋯
#    2 │ Forage trees                                        0.0               8
#    3 │ Legume forages                                      8.8
#                                                                2 columns omitted

# %%
plotconf(cf).f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
