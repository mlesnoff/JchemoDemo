# %%
using JLD2, CairoMakie, FreqTables
using Jchemo, JchemoData

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/forages2.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot = nro(X)
# Out:
# 485

# %%
@head X
# Out:
# ... (485, 700)
# 3×700 DataFrame
#  Row │ 1100          1102          1104         1106         1108         1110 ⋯
#      │ Float64       Float64       Float64      Float64      Float64      Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.000231591  -0.000175945  -8.48176e-5  2.05217e-5   0.000110094  0.00 ⋯
#    2 │ -9.66352e-5   -3.30928e-5    5.64966e-5  0.000154135  0.000237725  0.00
#    3 │ -0.000131769  -7.8398e-5     7.92223e-7  8.90044e-5   0.000160022  0.00
#                                                              695 columns omitted

# %%
@head Y
# Out:
# ... (485, 4)
# 3×4 DataFrame
#  Row │ dm        ndf       typ             test
#      │ Float64?  Float64?  String          Int64
# ─────┼───────────────────────────────────────────
#    1 │    92.23   37.58    Legume forages      1
#    2 │    93.26   49.6462  Legume forages      0
#    3 │    92.9    63.2939  Forage trees        0

# %%
y = Y.typ
tab(y)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "Cereal and grass forages" => 160
#   "Forage trees"             => 101
#   "Legume forages"           => 224

# %%
freqtable(y, Y.test)
# Out:
# 3×2 Named Matrix{Int64}
#              Dim1 ╲ Dim2 │   0    1
# ─────────────────────────┼─────────
# Cereal and grass forages │ 100   60
# Forage trees             │  56   45
# Legume forages           │ 167   57

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 700-element Vector{Float64}:
#  1100.0
#  1102.0
#  1104.0
#  1106.0
#  1108.0
#  1110.0
#  1112.0
#  1114.0
#  1116.0
#  1118.0
#     ⋮
#  2482.0
#  2484.0
#  2486.0
#  2488.0
#  2490.0
#  2492.0
#  2494.0
#  2496.0
#  2498.0

# %%
# X is already preprocessed
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = Bool.(Y.test)
Xtrain = rmrow(X, s)
ytrain = rmrow(y, s)
Xtest = X[s, :]
ytest = y[s]
ntrain = nro(Xtrain)
ntest = nro(Xtest)
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 485, ntrain = 323, ntest = 162)

# %%
# "PLSDA" gathers different methods
nlv = 15
fm = plsrda(Xtrain, ytrain; nlv = nlv) ;
#fm = plslda(Xtrain, ytrain; nlv = nlv) ;
#fm = plsqda(Xtrain, ytrain; nlv = nlv) ;
#fm = plsqda(Xtrain, ytrain; nlv = nlv, prior = "prop") ;

# Ridge (RR-DA)
#fm = rrda(Xtrain, ytrain; lb = 1e-5) ;

# %%
pnames(fm)
# Out:
# (:fm, :lev, :ni)

# %%
pnames(fm.fm)
# Out:
# (:T, :P, :R, :W, :C, :TT, :xmeans, :xscales, :ymeans, :yscales, :weights, :niter)

# %%
res = Jchemo.predict(fm, Xtest) ;
pnames(res)
# Out:
# (:pred, :posterior)

# %%
pred = res.pred
# Out:
# 162×1 Matrix{String}:
#  "Legume forages"
#  "Cereal and grass forages"
#  "Cereal and grass forages"
#  "Legume forages"
#  "Cereal and grass forages"
#  "Cereal and grass forages"
#  "Legume forages"
#  "Forage trees"
#  "Forage trees"
#  "Legume forages"
#  ⋮
#  "Cereal and grass forages"
#  "Cereal and grass forages"
#  "Forage trees"
#  "Forage trees"
#  "Legume forages"
#  "Legume forages"
#  "Legume forages"
#  "Legume forages"
#  "Legume forages"

# %%
res.posterior   # prediction of the dummy table
# Out:
# 162×3 Matrix{Float64}:
#  -0.00450279   0.0717177    0.932785
#   0.912764    -0.0344078    0.121644
#   1.07725     -0.00150365  -0.075744
#  -0.171714     0.40874      0.762974
#   1.14771     -0.118855    -0.0288524
#   0.856088     0.14677     -0.00285744
#  -0.0470334   -0.0116128    1.05865
#  -0.00170751   0.688917     0.31279
#  -0.0648639    1.09394     -0.0290799
#   0.078269     0.393216     0.528515
#   ⋮
#   0.70692     -0.285424     0.578504
#   0.89071     -0.0294659    0.138756
#   0.137108     0.660414     0.202478
#   0.0954742    0.915495    -0.0109697
#   0.250934     0.0870149    0.662051
#   0.0869541    0.273935     0.639111
#   0.114483    -0.0200331    0.905551
#   0.242255    -0.0180192    0.775764
#  -0.11913     -0.0662686    1.1854

# %%
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.1111111111111111

# %%
freqtable(ytest, vec(pred))
# Out:
# 3×3 Named Matrix{Int64}
#              Dim1 ╲ Dim2 │ Cereal and grass forages  …            Legume forages
# ─────────────────────────┼──────────────────────────────────────────────────────
# Cereal and grass forages │                       54  …                         5
# Forage trees             │                        0                           10
# Legume forages           │                        0  …                        55

# %%
cf = confusion(pred, ytest) ;
pnames(cf)
# Out:
# (:cnt, :pct, :A, :Apct, :accuracy, :lev)

# %%
cf.cnt
# Out:
# 3×4 DataFrame
#  Row │ y                         pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Int64                          Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                             54                 ⋯
#    2 │ Forage trees                                          0
#    3 │ Legume forages                                        0
#                                                                2 columns omitted

# %%
cf.pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           90.0                 ⋯
#    2 │ Forage trees                                        0.0               7
#    3 │ Legume forages                                      0.0
#                                                                2 columns omitted

# %%
cf.accuracy
# Out:
# 88.9

# %%
plotconf(cf).f
# Out:
# Figure()

# %%
# PLSDA with averaging
nlv = "0:20"
fm = plsrdaavg(Xtrain, ytrain; nlv = nlv) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.1111111111111111

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
