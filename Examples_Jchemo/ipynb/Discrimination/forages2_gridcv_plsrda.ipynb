#  [[1, 2, 4, 7, 9, 17, 20, 24, 27, 30  …  286, 287, 289, 295, 296, 304, 310, 312, 313, 317], [8, 12, 13, 14, 15, 19, 22, 25, 26, 29  …  300, 306, 307, 308, 309, 311, 314, 316, 318, 319], [3, 5, 6, 10, 11, 16, 18, 21, 23, 28  …  297, 301, 302, 303, 305, 315, 320, 321, 322, 323]]
#  [[4, 8, 9, 11, 17, 18, 19, 20, 22, 23  …  291, 292, 294, 295, 296, 303, 304, 312, 315, 320], [1, 3, 5, 10, 14, 21, 31, 32, 34, 35  …  305, 307, 308, 309, 311, 313, 314, 316, 321, 322], [2, 6, 7, 12, 13, 15, 16, 25, 29, 36  …  297, 298, 299, 301, 306, 310, 317, 318, 319, 323]]
#  [[2, 5, 15, 16, 17, 20, 21, 22, 25, 29  …  295, 299, 303, 305, 306, 312, 314, 317, 319, 322], [1, 4, 6, 8, 9, 11, 13, 14, 23, 26  …  284, 289, 296, 301, 302, 304, 310, 311, 315, 323], [3, 7, 10, 12, 18, 19, 24, 30, 34, 35  …  298, 300, 307, 308, 309, 313, 316, 318, 320, 321]]

# %%
nlv = 0:50
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plsrda, nlv = nlv, verbose = false).res
# Out:
# 51×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#    1 │     0  0.482993
#    2 │     1  0.286045
#    3 │     2  0.231565
#    4 │     3  0.211131
#    5 │     4  0.150453
#    6 │     5  0.135927
#    7 │     6  0.131274
#    8 │     7  0.123212
#   ⋮  │   ⋮       ⋮
#   45 │    44  0.110895
#   46 │    45  0.110577
#   47 │    46  0.111186
#   48 │    47  0.111803
#   49 │    48  0.113055
#   50 │    49  0.113361
#   51 │    50  0.112121
#         36 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#   28 │    27  0.101569

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = plsrda(Xtrain, ytrain; nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.09876543209876543

# %%
cf = confusion(pred, ytest) ;
cf.cnt
# Out:
# 3×4 DataFrame
#  Row │ y                         pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Int64                          Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                             53                 ⋯
#    2 │ Forage trees                                          0
#    3 │ Legume forages                                        0
#                                                                2 columns omitted

# %%
cf.pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           88.3                 ⋯
#    2 │ Forage trees                                        0.0               8
#    3 │ Legume forages                                      0.0
#                                                                2 columns omitted

# %%
plotconf(cf).f
# Out:
# Figure()

# %%
# PLSLDA
nlv = 1:50  ## !!: Does not start from nlv=0 (since LDA on scores)
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plslda, nlv = nlv, verbose = false).res
# Out:
# 50×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#    1 │     1  0.279869
#    2 │     2  0.214858
#    3 │     3  0.20587
#    4 │     4  0.159715
#    5 │     5  0.13807
#    6 │     6  0.124452
#    7 │     7  0.124143
#    8 │     8  0.124143
#   ⋮  │   ⋮       ⋮
#   44 │    44  0.108397
#   45 │    45  0.109326
#   46 │    46  0.110243
#   47 │    47  0.111486
#   48 │    48  0.690369
#   49 │    49  0.690369
#   50 │    50  0.690369
#         35 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#   32 │    32  0.103104

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = plslda(Xtrain, ytrain; nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.08024691358024691

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
