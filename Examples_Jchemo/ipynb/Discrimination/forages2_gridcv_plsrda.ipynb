#  [[6, 9, 10, 18, 19, 20, 21, 22, 23, 25  …  299, 300, 305, 306, 310, 313, 314, 316, 320, 323], [2, 3, 4, 7, 11, 13, 15, 17, 24, 28  …  298, 301, 302, 309, 311, 312, 315, 317, 318, 322], [1, 5, 8, 12, 14, 16, 26, 29, 31, 32  …  284, 286, 289, 290, 303, 304, 307, 308, 319, 321]]
#  [[5, 9, 10, 16, 19, 23, 27, 32, 33, 35  …  302, 307, 308, 309, 311, 312, 313, 314, 315, 322], [3, 4, 7, 8, 12, 17, 20, 22, 24, 29  …  268, 270, 281, 290, 292, 295, 299, 317, 319, 320], [1, 2, 6, 11, 13, 14, 15, 18, 21, 25  …  301, 303, 304, 305, 306, 310, 316, 318, 321, 323]]
#  [[2, 3, 4, 5, 6, 7, 8, 9, 13, 14  …  301, 308, 309, 313, 314, 315, 317, 319, 320, 323], [1, 15, 18, 20, 22, 31, 32, 34, 37, 38  …  291, 292, 296, 300, 305, 306, 307, 310, 312, 316], [10, 11, 12, 25, 28, 29, 33, 35, 36, 39  …  295, 298, 299, 302, 303, 304, 311, 318, 321, 322]]

# %%
nlv = 0:50
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plsrda, nlv = nlv, verbose = false).res
# Out:
# 51×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#    1 │     0  0.482921
#    2 │     1  0.284773
#    3 │     2  0.227856
#    4 │     3  0.20433
#    5 │     4  0.150802
#    6 │     5  0.136235
#    7 │     6  0.129125
#    8 │     7  0.121697
#   ⋮  │   ⋮       ⋮
#   45 │    44  0.104644
#   46 │    45  0.103712
#   47 │    46  0.105261
#   48 │    47  0.10743
#   49 │    48  0.108979
#   50 │    49  0.109288
#   51 │    50  0.110214
#         36 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#   40 │    39  0.100943

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = plsrda(Xtrain, ytrain; nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.09259259259259259

# %%
cf = confusion(pred, ytest) ;
cf.cnt
# Out:
# 3×4 DataFrame
#  Row │ y                         pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Int64                          Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                             55                 ⋯
#    2 │ Forage trees                                          0
#    3 │ Legume forages                                        0
#                                                                2 columns omitted

# %%
cf.pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           91.7                 ⋯
#    2 │ Forage trees                                        0.0               8
#    3 │ Legume forages                                      0.0
#                                                                2 columns omitted

# %%
plotconf(cf).f
# Out:
# Figure()

# %%
# PLSLDA
nlv = 1:50  ## !!: Does not start from nlv=0 (since LDA on scores)
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plslda, nlv = nlv, verbose = false).res
# Out:
# 50×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#    1 │     1  0.279526
#    2 │     2  0.219514
#    3 │     3  0.205302
#    4 │     4  0.147392
#    5 │     5  0.136226
#    6 │     6  0.130033
#    7 │     7  0.122912
#    8 │     8  0.124772
#   ⋮  │   ⋮       ⋮
#   44 │    44  0.103718
#   45 │    45  0.102786
#   46 │    46  0.104953
#   47 │    47  0.10495
#   48 │    48  0.690412
#   49 │    49  0.690412
#   50 │    50  0.690412
#         35 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#   39 │    39  0.098777

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = plslda(Xtrain, ytrain; nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.09259259259259259

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
