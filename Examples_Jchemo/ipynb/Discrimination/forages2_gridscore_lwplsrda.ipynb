# %%
using JLD2, CairoMakie
using StatsBase, FreqTables
using Jchemo, JchemoData

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/forages2.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot = nro(X)
# Out:
# 485

# %%
@head X
# Out:
# ... (485, 700)
# 3×700 DataFrame
#  Row │ 1100          1102          1104         1106         1108         1110 ⋯
#      │ Float64       Float64       Float64      Float64      Float64      Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.000231591  -0.000175945  -8.48176e-5  2.05217e-5   0.000110094  0.00 ⋯
#    2 │ -9.66352e-5   -3.30928e-5    5.64966e-5  0.000154135  0.000237725  0.00
#    3 │ -0.000131769  -7.8398e-5     7.92223e-7  8.90044e-5   0.000160022  0.00
#                                                              695 columns omitted

# %%
@head Y
# Out:
# ... (485, 4)
# 3×4 DataFrame
#  Row │ dm        ndf       typ             test
#      │ Float64?  Float64?  String          Int64
# ─────┼───────────────────────────────────────────
#    1 │    92.23   37.58    Legume forages      1
#    2 │    93.26   49.6462  Legume forages      0
#    3 │    92.9    63.2939  Forage trees        0

# %%
y = Y.typ
tab(y)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "Cereal and grass forages" => 160
#   "Forage trees"             => 101
#   "Legume forages"           => 224

# %%
freqtable(y, Y.test)
# Out:
# 3×2 Named Matrix{Int64}
#              Dim1 ╲ Dim2 │   0    1
# ─────────────────────────┼─────────
# Cereal and grass forages │ 100   60
# Forage trees             │  56   45
# Legume forages           │ 167   57

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 700-element Vector{Float64}:
#  1100.0
#  1102.0
#  1104.0
#  1106.0
#  1108.0
#  1110.0
#  1112.0
#  1114.0
#  1116.0
#  1118.0
#     ⋮
#  2482.0
#  2484.0
#  2486.0
#  2488.0
#  2490.0
#  2492.0
#  2494.0
#  2496.0
#  2498.0

# %%
# X is already preprocessed
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = Bool.(Y.test)
Xtrain = rmrow(X, s)
ytrain = rmrow(y, s)
Xtest = X[s, :]
ytest = y[s]
ntrain = nro(Xtrain)
ntest = nro(Xtest)
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 485, ntrain = 323, ntest = 162)

# %%
# Train ==> Cal + Val
pct = .30
nval = Int64.(round(pct * ntrain))
ncal = ntrain - nval
s = sample(1:ntrain, nval; replace = false)
Xcal = rmrow(Xtrain, s)
ycal = rmrow(ytrain, s)
Xval = Xtrain[s, :]
yval = ytrain[s]
(ntot = ntot, ntrain, ncal, nval, ntest)
# Out:
# (ntot = 485, ntrain = 323, ncal = 226, nval = 97, ntest = 162)

# %%
nlvdis = [15; 25] ; metric = ["mahal"]
h = [1; 2; 5] ; k = [100; 200; 300]
nlv = 0:15
pars = mpar(nlvdis = nlvdis, metric = metric,
    h = h, k = k)
# Out:
# (nlvdis = Any[15, 25, 15, 25, 15, 25, 15, 25, 15, 25, 15, 25, 15, 25, 15, 25, 15, 25], metric = Any["mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"], h = Any[1, 1, 2, 2, 5, 5, 1, 1, 2, 2, 5, 5, 1, 1, 2, 2, 5, 5], k = Any[100, 100, 100, 100, 100, 100, 200, 200, 200, 200, 200, 200, 300, 300, 300, 300, 300, 300])

# %%
length(pars[1])
# Out:
# 18

# %%
res = gridscorelv(Xcal, ycal, Xval, yval;
    score = err, fun = lwplsrda, nlv = nlv, pars = pars,
    verbose = false)
# Out:
# 288×6 DataFrame
#  Row │ nlvdis  metric  h    k    nlv    y1
#      │ Any     Any     Any  Any  Int64  Float64
# ─────┼────────────────────────────────────────────
#    1 │ 15      mahal   1    100      0  0.103093
#    2 │ 15      mahal   1    100      1  0.0824742
#    3 │ 15      mahal   1    100      2  0.0515464
#    4 │ 15      mahal   1    100      3  0.0618557
#    5 │ 15      mahal   1    100      4  0.0412371
#    6 │ 15      mahal   1    100      5  0.0515464
#    7 │ 15      mahal   1    100      6  0.0618557
#    8 │ 15      mahal   1    100      7  0.0515464
#   ⋮  │   ⋮       ⋮      ⋮    ⋮     ⋮        ⋮
#  282 │ 25      mahal   5    300      9  0.113402
#  283 │ 25      mahal   5    300     10  0.0824742
#  284 │ 25      mahal   5    300     11  0.113402
#  285 │ 25      mahal   5    300     12  0.123711
#  286 │ 25      mahal   5    300     13  0.113402
#  287 │ 25      mahal   5    300     14  0.0824742
#  288 │ 25      mahal   5    300     15  0.0824742
#                                   273 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlvdis  metric  h    k    nlv    y1
#      │ Any     Any     Any  Any  Int64  Float64
# ─────┼────────────────────────────────────────────
#   37 │ 15      mahal   2    100      4  0.0309278

# %%
group = string.("metric=", res.metric, res.nlvdis, " h=", res.h,
    " k=", res.k)
# Out:
# 288-element Vector{String}:
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  "metric=mahal15 h=1 k=100"
#  ⋮
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"
#  "metric=mahal25 h=5 k=300"

# %%
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel = "Nb. LVs", ylabel = "ERR").f
# Out:
# Figure()

# %%
fm = lwplsrda(Xtrain, ytrain; nlvdis = res.nlvdis[u],
    metric = res.metric[u], h = res.h[u], k = res.k[u],
    nlv = res.nlv[u], verbose = false) ;
pred = Jchemo.predict(fm, Xtest).pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.07407407407407407

# %%
cf = confusion(pred, ytest) ;
cf.cnt
# Out:
# 3×4 DataFrame
#  Row │ y                         pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Int64                          Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                             55                 ⋯
#    2 │ Forage trees                                          1
#    3 │ Legume forages                                        3
#                                                                2 columns omitted

# %%
cf.pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           91.7                 ⋯
#    2 │ Forage trees                                        2.2               9
#    3 │ Legume forages                                      5.3
#                                                                2 columns omitted

# %%
plotconf(cf).f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
