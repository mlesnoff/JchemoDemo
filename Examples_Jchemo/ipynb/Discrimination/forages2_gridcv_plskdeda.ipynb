#  [[5, 7, 13, 14, 15, 18, 19, 22, 28, 32  …  296, 299, 301, 302, 304, 305, 306, 312, 313, 316], [1, 2, 4, 6, 8, 9, 11, 12, 23, 24  …  290, 291, 293, 297, 300, 310, 311, 314, 319, 322], [3, 10, 16, 17, 20, 21, 25, 26, 27, 29  …  303, 307, 308, 309, 315, 317, 318, 320, 321, 323]]
#  [[3, 4, 6, 9, 13, 16, 19, 22, 23, 25  …  284, 293, 296, 298, 299, 303, 304, 309, 313, 320], [7, 8, 11, 12, 21, 24, 26, 30, 34, 36  …  301, 302, 305, 308, 312, 314, 316, 318, 321, 323], [1, 2, 5, 10, 14, 15, 17, 18, 20, 27  …  297, 300, 306, 307, 310, 311, 315, 317, 319, 322]]

# %%
# PLS-LDA
nlv = 1:50
rescv = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plslda, nlv = nlv) ;
res = rescv.res
# Out:
# 50×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#    1 │     1  0.280856
#    2 │     2  0.21864
#    3 │     3  0.207174
#    4 │     4  0.150825
#    5 │     5  0.135358
#    6 │     6  0.122978
#    7 │     7  0.126696
#    8 │     8  0.125138
#   ⋮  │   ⋮       ⋮
#   44 │    44  0.109628
#   45 │    45  0.10962
#   46 │    46  0.109926
#   47 │    47  0.113641
#   48 │    48  0.690383
#   49 │    49  0.690383
#   50 │    50  0.690383
#         35 rows omitted

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "Err-CV").f
# Out:
# Figure()

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#   41 │    41  0.107777

# %%
fm = plslda(Xtrain, ytrain; nlv = res.nlv[u]) ;
res = Jchemo.predict(fm, Xtest) ;
pred = res.pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.1111111111111111

# %%
confusion(pred, ytest).pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           90.0                 ⋯
#    2 │ Forage trees                                        0.0               7
#    3 │ Legume forages                                      0.0
#                                                                2 columns omitted

# %%
# PLS-KDE-DA
pars = mpar(a = [.5, 1, 1.5])
# Out:
# (a = [0.5, 1.0, 1.5],)

# %%
nlv = 1:50
rescv = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plskdeda, pars = pars, nlv = nlv) ;
res = rescv.res
# Out:
# 150×3 DataFrame
#  Row │ nlv    a        y1
#      │ Int64  Float64  Float64
# ─────┼──────────────────────────
#    1 │     1      0.5  0.300335
#    2 │     2      0.5  0.235981
#    3 │     3      0.5  0.21825
#    4 │     4      0.5  0.169646
#    5 │     5      0.5  0.145835
#    6 │     6      0.5  0.134046
#    7 │     7      0.5  0.130365
#    8 │     8      0.5  0.122938
#   ⋮  │   ⋮       ⋮        ⋮
#  144 │    44      1.5  0.18267
#  145 │    45      1.5  0.180201
#  146 │    46      1.5  0.183619
#  147 │    47      1.5  0.181741
#  148 │    48      1.5  0.182044
#  149 │    49      1.5  0.184213
#  150 │    50      1.5  0.18794
#                 135 rows omitted

# %%
group = string.("a = ", res.a)
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel = "Nb. LVs", ylabel = "Err-CV").f
# Out:
# Figure()

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    a        y1
#      │ Int64  Float64  Float64
# ─────┼───────────────────────────
#   63 │    13      1.0  0.0950704

# %%
fm = plskdeda(Xtrain, ytrain; nlv = res.nlv[u],
    a = res.a[u]) ;
res = Jchemo.predict(fm, Xtest) ;
pred = res.pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.06790123456790123

# %%
confusion(pred, ytest).pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           95.0                 ⋯
#    2 │ Forage trees                                        0.0               9
#    3 │ Legume forages                                      3.5
#                                                                2 columns omitted

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
