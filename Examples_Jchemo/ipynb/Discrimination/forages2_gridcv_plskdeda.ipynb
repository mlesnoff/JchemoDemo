#  [[1, 3, 5, 6, 15, 20, 21, 22, 25, 26  …  293, 294, 301, 302, 303, 311, 314, 316, 317, 319], [4, 7, 8, 9, 10, 11, 13, 16, 17, 18  …  305, 306, 312, 313, 315, 318, 320, 321, 322, 323], [2, 12, 14, 24, 29, 30, 31, 34, 35, 38  …  291, 292, 295, 296, 298, 300, 307, 308, 309, 310]]
#  [[1, 2, 10, 11, 13, 15, 19, 34, 41, 51  …  300, 301, 304, 306, 313, 315, 318, 319, 321, 323], [3, 7, 9, 12, 16, 21, 24, 26, 28, 31  …  280, 281, 289, 302, 303, 310, 312, 314, 316, 317], [4, 5, 6, 8, 14, 17, 18, 20, 22, 23  …  296, 297, 299, 305, 307, 308, 309, 311, 320, 322]]

# %%
# PLS-LDA
nlv = 1:50
rescv = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plslda, nlv = nlv) ;
res = rescv.res
# Out:
# 50×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#    1 │     1  0.274608
#    2 │     2  0.223552
#    3 │     3  0.207759
#    4 │     4  0.143945
#    5 │     5  0.135272
#    6 │     6  0.121042
#    7 │     7  0.116104
#    8 │     8  0.116404
#   ⋮  │   ⋮        ⋮
#   44 │    44  0.0980933
#   45 │    45  0.100883
#   46 │    46  0.101517
#   47 │    47  0.10523
#   48 │    48  0.690472
#   49 │    49  0.690472
#   50 │    50  0.690472
#          35 rows omitted

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "Err-CV").f
# Out:
# Figure()

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼──────────────────
#   31 │    31  0.0946983

# %%
fm = plslda(Xtrain, ytrain; nlv = res.nlv[u]) ;
res = Jchemo.predict(fm, Xtest) ;
pred = res.pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.07407407407407407

# %%
confusion(pred, ytest).pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           93.3                 ⋯
#    2 │ Forage trees                                        0.0               8
#    3 │ Legume forages                                      0.0
#                                                                2 columns omitted

# %%
# PLS-KDE-DA
pars = mpar(a = [.5, 1, 1.5])
# Out:
# (a = [0.5, 1.0, 1.5],)

# %%
nlv = 1:50
rescv = gridcvlv(Xtrain, ytrain; segm = segm,
    score = err, fun = plskdeda, pars = pars, nlv = nlv) ;
res = rescv.res
# Out:
# 150×3 DataFrame
#  Row │ nlv    a        y1
#      │ Int64  Float64  Float64
# ─────┼──────────────────────────
#    1 │     1      0.5  0.293821
#    2 │     2      0.5  0.237201
#    3 │     3      0.5  0.209303
#    4 │     4      0.5  0.160638
#    5 │     5      0.5  0.136495
#    6 │     6      0.5  0.126918
#    7 │     7      0.5  0.121028
#    8 │     8      0.5  0.113295
#   ⋮  │   ⋮       ⋮        ⋮
#  144 │    44      1.5  0.171115
#  145 │    45      1.5  0.169877
#  146 │    46      1.5  0.17421
#  147 │    47      1.5  0.176679
#  148 │    48      1.5  0.178848
#  149 │    49      1.5  0.182249
#  150 │    50      1.5  0.185958
#                 135 rows omitted

# %%
group = string.("a = ", res.a)
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel = "Nb. LVs", ylabel = "Err-CV").f
# Out:
# Figure()

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    a        y1
#      │ Int64  Float64  Float64
# ─────┼───────────────────────────
#   67 │    17      1.0  0.0882024

# %%
fm = plskdeda(Xtrain, ytrain; nlv = res.nlv[u],
    a = res.a[u]) ;
res = Jchemo.predict(fm, Xtest) ;
pred = res.pred
err(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.06790123456790123

# %%
confusion(pred, ytest).pct
# Out:
# 3×4 DataFrame
#  Row │ levels                    pred_Cereal and grass forages  pred_Forage tr ⋯
#      │ String                    Float64                        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Cereal and grass forages                           96.7                 ⋯
#    2 │ Forage trees                                        0.0               9
#    3 │ Legume forages                                      3.5
#                                                                2 columns omitted

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
