# %%
using JLD2, CairoMakie, StatsBase
using Jchemo, JchemoData

# %%
using JchemoData, JLD2, CairoMakie
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/cassav.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
y = dat.Y.tbc
year = dat.Y.year
# Out:
# 280-element Vector{Int64}:
#  2009
#  2009
#  2009
#  2009
#  2009
#  2009
#  2009
#  2009
#  2009
#  2009
#     ⋮
#  2013
#  2013
#  2013
#  2013
#  2013
#  2013
#  2013
#  2013
#  2013

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 1050-element Vector{Float64}:
#   400.0
#   402.0
#   404.0
#   406.0
#   408.0
#   410.0
#   412.0
#   414.0
#   416.0
#   418.0
#     ⋮
#  2482.0
#  2484.0
#  2486.0
#  2488.0
#  2490.0
#  2492.0
#  2494.0
#  2496.0
#  2498.0

# %%
tab(year)
# Out:
# OrderedCollections.OrderedDict{Int64, Int64} with 5 entries:
#   2009 => 42
#   2010 => 47
#   2011 => 40
#   2012 => 71
#   2013 => 80

# %%
# Tot ==> Train + Test
s = year .<= 2012
Xtrain = X[s, :]
ytrain = y[s]
Xtest = rmrow(X, s)
ytest = rmrow(y, s)
ntrain = nro(Xtrain)
ntest = nro(Xtest)
ntot = ntrain + ntest
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 280, ntrain = 200, ntest = 80)

# %%
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
f = 15 ; pol = 3 ; d = 2
Xp = savgol(snv(X); f = f, pol = pol, d = d)

plotsp(Xp, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
# Train ==> Cal + Val
nval = Int64(round(.30 * ntrain))
s = sampsys(ytrain; k = nval).train
ytrain[s]
Xcal = rmrow(Xtrain, s)
ycal = rmrow(ytrain, s)
Xval = Xtrain[s, :]
yval = ytrain[s, :]
ncal = ntrain - nval
(ntot = ntot, ntrain, ntest, ncal, nval)
# Out:
# (ntot = 280, ntrain = 200, ntest = 80, ncal = 140, nval = 60)

# %%
# PLSR
nlv = 0:40
res = gridscorelv(Xcal, ycal, Xval, yval;
    score = rmsep, fun = plskern, nlv = nlv)
# Out:
# 41×2 DataFrame
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#    1 │     0  3.05343
#    2 │     1  2.75697
#    3 │     2  2.28919
#    4 │     3  2.19068
#    5 │     4  1.05577
#    6 │     5  0.980032
#    7 │     6  0.85428
#    8 │     7  0.81996
#   ⋮  │   ⋮       ⋮
#   35 │    34  1.62115
#   36 │    35  1.60578
#   37 │    36  1.64538
#   38 │    37  1.65566
#   39 │    38  1.65866
#   40 │    39  1.62974
#   41 │    40  1.6134
#         26 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    y1
#      │ Int64  Float64
# ─────┼─────────────────
#   13 │    12  0.801786

# %%
plotgrid(res.nlv, res.y1; step = 5,
    xlabel = "Nb. LVs", ylabel = "RMSEP").f
# Out:
# Figure()

# %%
fm = plskern(Xtrain, ytrain; nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred ;
@show rmsep(pred, ytest)
mse(pred, ytest)
# Out:
# rmsep(pred, ytest) = [1.5373184736097893;;]
# 1×10 DataFrame
#  Row │ nam     msep     rmsep    sep      bias     cor2     r2       rpd       ⋯
#      │ String  Float64  Float64  Float64  Float64  Float64  Float64  Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ y1        2.363    1.537    1.097   -1.077    0.949    0.836    2.467   ⋯
#                                                                2 columns omitted

# %%
f, ax = plotxy(vec(pred), ytest; color = (:red, .5),
    xlabel = "Predicted", ylabel = "Observed (Test)",
    resolution = (450, 350))
ablines!(ax, 0, 1)
f
# Out:
# Figure()

# %%
# LWMLR-S with a PCA-score space = "LWR" (Naes et al.1990)
reduc = ["pca"]
nlv = Int64.(LinRange(5, 20, 4))
metric = ["eucl", "mahal"]
h = [1; 2; 6] ; k = [50; 100; 150]
pars = mpar(reduc = reduc, nlv = nlv,
    metric = metric, h = h, k = k)
length(pars[1])
# Out:
# 72

# %%
res = gridscore(Xcal, ycal, Xval, yval;
    score = rmsep, fun = lwmlr_s, pars = pars,
    verbose = false)
# Out:
# 72×6 DataFrame
#  Row │ reduc  nlv  metric  h    k    y1
#      │ Any    Any  Any     Any  Any  Float64
# ─────┼────────────────────────────────────────
#    1 │ pca    5    eucl    1    50   1.16887
#    2 │ pca    10   eucl    1    50   0.974146
#    3 │ pca    15   eucl    1    50   0.916437
#    4 │ pca    20   eucl    1    50   0.994857
#    5 │ pca    5    mahal   1    50   1.24864
#    6 │ pca    10   mahal   1    50   1.11335
#    7 │ pca    15   mahal   1    50   1.0669
#    8 │ pca    20   mahal   1    50   1.40719
#   ⋮  │   ⋮     ⋮     ⋮      ⋮    ⋮      ⋮
#   66 │ pca    10   eucl    6    150  0.895545
#   67 │ pca    15   eucl    6    150  0.804167
#   68 │ pca    20   eucl    6    150  0.799754
#   69 │ pca    5    mahal   6    150  1.09858
#   70 │ pca    10   mahal   6    150  0.898406
#   71 │ pca    15   mahal   6    150  0.802649
#   72 │ pca    20   mahal   6    150  0.791875
#                                57 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ reduc  nlv  metric  h    k    y1
#      │ Any    Any  Any     Any  Any  Float64
# ─────┼───────────────────────────────────────
#   64 │ pca    20   mahal   2    150  0.78213

# %%
fm = lwmlr_s(Xtrain, ytrain; reduc = res.reduc[u],
    nlv = res.nlv[u], metric = res.metric[u],
    h = res.h[u], k = res.k[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
mse(pred, ytest)
# Out:
# rmsep(pred, ytest) = [1.5158702643408855;;]
# 1×10 DataFrame
#  Row │ nam     msep     rmsep    sep      bias     cor2     r2       rpd       ⋯
#      │ String  Float64  Float64  Float64  Float64  Float64  Float64  Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ y1        2.298    1.516    1.207   -0.917     0.92     0.84    2.501   ⋯
#                                                                2 columns omitted

# %%
plotxy(vec(pred), ytest; color = (:red, .5),
    bisect = true, xlabel = "Prediction",
    ylabel = "Observed (Test)").f
# Out:
# Figure()

# %%
# LWMLR-S with a PLS-score space
reduc = ["pls"]
nlv = Int64.(LinRange(5, 20, 4))
metric = ["eucl", "mahal"]
h = [1; 2; 6] ; k = [50; 100; 150]
pars = mpar(reduc = reduc, nlv = nlv,
    metric = metric, h = h, k = k)
length(pars[1])
# Out:
# 72

# %%
res = gridscore(Xcal, ycal, Xval, yval;
    score = rmsep, fun = lwmlr_s, pars = pars,
    verbose = false)
# Out:
# 72×6 DataFrame
#  Row │ reduc  nlv  metric  h    k    y1
#      │ Any    Any  Any     Any  Any  Float64
# ─────┼────────────────────────────────────────
#    1 │ pls    5    eucl    1    50   1.07489
#    2 │ pls    10   eucl    1    50   0.819965
#    3 │ pls    15   eucl    1    50   0.965827
#    4 │ pls    20   eucl    1    50   1.28467
#    5 │ pls    5    mahal   1    50   1.1621
#    6 │ pls    10   mahal   1    50   0.927165
#    7 │ pls    15   mahal   1    50   1.12038
#    8 │ pls    20   mahal   1    50   1.44187
#   ⋮  │   ⋮     ⋮     ⋮      ⋮    ⋮      ⋮
#   66 │ pls    10   eucl    6    150  0.821489
#   67 │ pls    15   eucl    6    150  0.849158
#   68 │ pls    20   eucl    6    150  1.05435
#   69 │ pls    5    mahal   6    150  0.985775
#   70 │ pls    10   mahal   6    150  0.817038
#   71 │ pls    15   mahal   6    150  0.846359
#   72 │ pls    20   mahal   6    150  1.05992
#                                57 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ reduc  nlv  metric  h    k    y1
#      │ Any    Any  Any     Any  Any  Float64
# ─────┼────────────────────────────────────────
#   38 │ pls    10   mahal   2    100  0.784083

# %%
fm = lwmlr_s(Xtrain, ytrain; reduc = res.reduc[u],
    nlv = res.nlv[u], metric = res.metric[u],
    h = res.h[u], k = res.k[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
mse(pred, ytest)
# Out:
# rmsep(pred, ytest) = [1.2144079252900708;;]
# 1×10 DataFrame
#  Row │ nam     msep     rmsep    sep      bias     cor2     r2       rpd       ⋯
#      │ String  Float64  Float64  Float64  Float64  Float64  Float64  Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ y1        1.475    1.214    0.932   -0.779    0.956    0.897    3.122   ⋯
#                                                                2 columns omitted

# %%
plotxy(vec(pred), ytest; color = (:red, .5),
    bisect = true, xlabel = "Prediction",
    ylabel = "Observed (Test)").f
# Out:
# Figure()

# %%
# LWMLR-S with a DKPLS-score space
reduc = ["dkpls"]
nlv = Int64.(LinRange(5, 20, 4))
metric = ["eucl", "mahal"]
h = [1; 2; 6] ; k = [50; 100; 150]
gamma = 10.0.^(-2:3)
pars = mpar(reduc = reduc, nlv = nlv, metric = metric,
    h = h, k = k, gamma = gamma, )
length(pars[1])
# Out:
# 432

# %%
res = gridscore(Xcal, ycal, Xval, yval;
    score = rmsep, fun = lwmlr_s, pars = pars,
    verbose = false)
# Out:
# 432×7 DataFrame
#  Row │ reduc  nlv  metric  h    k    gamma   y1
#      │ Any    Any  Any     Any  Any  Any     Float64
# ─────┼───────────────────────────────────────────────
#    1 │ dkpls  5    eucl    1    50   0.01    1.95776
#    2 │ dkpls  10   eucl    1    50   0.01    1.10888
#    3 │ dkpls  15   eucl    1    50   0.01    1.1421
#    4 │ dkpls  20   eucl    1    50   0.01    1.10882
#    5 │ dkpls  5    mahal   1    50   0.01    2.02716
#    6 │ dkpls  10   mahal   1    50   0.01    1.11935
#    7 │ dkpls  15   mahal   1    50   0.01    1.31645
#    8 │ dkpls  20   mahal   1    50   0.01    1.31306
#   ⋮  │   ⋮     ⋮     ⋮      ⋮    ⋮     ⋮        ⋮
#  426 │ dkpls  10   eucl    6    150  1000.0  3.61047
#  427 │ dkpls  15   eucl    6    150  1000.0  3.60435
#  428 │ dkpls  20   eucl    6    150  1000.0  3.59625
#  429 │ dkpls  5    mahal   6    150  1000.0  3.60963
#  430 │ dkpls  10   mahal   6    150  1000.0  3.61047
#  431 │ dkpls  15   mahal   6    150  1000.0  3.60435
#  432 │ dkpls  20   mahal   6    150  1000.0  3.59624
#                                      417 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ reduc  nlv  metric  h    k    gamma  y1
#      │ Any    Any  Any     Any  Any  Any    Float64
# ─────┼───────────────────────────────────────────────
#   56 │ dkpls  20   mahal   1    150  0.01   0.895641

# %%
fm = lwmlr_s(Xtrain, ytrain; reduc = res.reduc[u],
    metric = res.metric[u], nlv = res.nlv[u],
    h = res.h[u], k = res.k[u], gamma = res.gamma[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
mse(pred, ytest)
# Out:
# rmsep(pred, ytest) = [1.1279387597465138;;]
# 1×10 DataFrame
#  Row │ nam     msep     rmsep    sep      bias     cor2     r2       rpd       ⋯
#      │ String  Float64  Float64  Float64  Float64  Float64  Float64  Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ y1        1.272    1.128    1.039   -0.438    0.932    0.912    3.362   ⋯
#                                                                2 columns omitted

# %%
plotxy(vec(pred), ytest; color = (:red, .5),
    bisect = true, xlabel = "Prediction",
    ylabel = "Observed (Test)").f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
