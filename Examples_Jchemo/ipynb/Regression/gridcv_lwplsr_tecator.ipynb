# %%
using JLD2, CairoMakie
using Jchemo, JchemoData

# %%
path_pack = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_pack, "data/tecator.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot, p = size(X)
# Out:
# (178, 100)

# %%
@head X
# Out:
# ... (178, 100)
# 3×100 DataFrame
#  Row │ 850      852      854      856      858      860      862      864      ⋯
#      │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2.61776  2.61814  2.61859  2.61912  2.61981  2.62071  2.62186  2.62334  ⋯
#    2 │ 2.83454  2.83871  2.84283  2.84705  2.85138  2.85587  2.8606   2.86566
#    3 │ 2.58284  2.58458  2.58629  2.58808  2.58996  2.59192  2.59401  2.59627
#                                                               92 columns omitted

# %%
@head Y
# Out:
# ... (178, 4)
# 3×4 DataFrame
#  Row │ water    fat      protein  typ
#      │ Float64  Float64  Float64  String
# ─────┼───────────────────────────────────
#    1 │    60.5     22.5     16.7  train
#    2 │    46.0     40.1     13.5  train
#    3 │    71.0      8.4     20.5  train

# %%
summ(Y)
# Out:
# (res = 4×7 DataFrame
#  Row │ variable  mean    std     min   max   n      nmissing
#      │ Symbol    Union…  Union…  Any   Any   Int64  Int64
# ─────┼───────────────────────────────────────────────────────
#    1 │ water     63.046  9.784   39.3  76.6    178         0
#    2 │ fat       18.378  12.629  0.9   49.1    178         0
#    3 │ protein   17.634  2.996   11.0  21.8    178         0
#    4 │ typ                       test  val     178         0, ntot = 178)

# %%
namy = names(Y)[1:3]
# Out:
# 3-element Vector{String}:
#  "water"
#  "fat"
#  "protein"

# %%
typ = Y.typ
tab(typ)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "test"  => 31
#   "train" => 115
#   "val"   => 32

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 100-element Vector{Float64}:
#   850.0
#   852.0
#   854.0
#   856.0
#   858.0
#   860.0
#   862.0
#   864.0
#   866.0
#   868.0
#     ⋮
#  1032.0
#  1034.0
#  1036.0
#  1038.0
#  1040.0
#  1042.0
#  1044.0
#  1046.0
#  1048.0

# %%
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
f = 15 ; pol = 3 ; d = 2
Xp = savgol(snv(X); f = f, pol = pol, d = d)

plotsp(Xp, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = typ .== "train"
Xtrain = Xp[s, :]
Ytrain = Y[s, namy]
Xtest = rmrow(Xp, s)
Ytest = rmrow(Y[:, namy], s)
ntrain = nro(Xtrain)
ntest = nro(Xtest)
ntot = ntrain + ntest
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 178, ntrain = 115, ntest = 63)

# %%
j = 2
nam = namy[j]    # y-variable
ytrain = Ytrain[:, nam]
ytest = Ytest[:, nam]
# Out:
# 63-element Vector{Float64}:
#  29.8
#   1.4
#   4.6
#  11.0
#  17.0
#  22.4
#  27.9
#  46.5
#   6.1
#   2.0
#   ⋮
#  18.1
#  19.4
#  24.8
#  27.2
#  28.4
#  31.3
#  33.8
#  35.5
#  42.5

# %%
segm = segmkf(ntrain, 4; rep = 5)
# Out:
# 5-element Vector{Any}:
#  [[4, 6, 9, 12, 15, 21, 22, 24, 27, 29  …  88, 90, 91, 99, 105, 106, 111, 112, 113, 115], [2, 7, 11, 14, 28, 33, 35, 38, 42, 59  …  89, 92, 93, 96, 97, 98, 101, 103, 109, 110], [1, 8, 10, 13, 16, 17, 18, 23, 30, 36  …  77, 81, 83, 85, 94, 95, 100, 102, 104, 114], [3, 5, 19, 20, 25, 26, 32, 34, 37, 39  …  60, 61, 64, 69, 72, 75, 76, 87, 107, 108]]
#  [[5, 7, 10, 12, 15, 16, 18, 20, 26, 33  …  69, 70, 73, 79, 80, 84, 87, 93, 111, 114], [3, 17, 24, 30, 31, 34, 36, 40, 47, 48  …  78, 82, 83, 86, 94, 105, 106, 110, 113, 115], [4, 6, 8, 9, 11, 14, 22, 23, 25, 27  …  88, 90, 91, 95, 97, 98, 101, 103, 107, 112], [1, 2, 13, 19, 21, 29, 32, 35, 37, 39  …  85, 89, 92, 96, 99, 100, 102, 104, 108, 109]]
#  [[8, 9, 10, 11, 22, 27, 28, 30, 42, 47  …  90, 93, 94, 97, 98, 100, 103, 104, 105, 112], [3, 12, 15, 17, 20, 23, 25, 31, 39, 40  …  81, 82, 83, 84, 86, 91, 95, 108, 111, 114], [2, 6, 13, 14, 18, 19, 29, 32, 34, 35  …  73, 74, 87, 89, 96, 99, 107, 109, 113, 115], [1, 4, 5, 7, 16, 21, 24, 26, 33, 36  …  63, 70, 75, 77, 85, 92, 101, 102, 106, 110]]
#  [[2, 6, 7, 8, 16, 19, 23, 33, 35, 45  …  82, 83, 85, 86, 90, 92, 107, 108, 112, 114], [1, 9, 12, 15, 17, 18, 20, 22, 30, 34  …  72, 76, 80, 87, 91, 94, 97, 99, 102, 115], [3, 4, 10, 25, 28, 29, 36, 39, 48, 53  …  84, 88, 89, 95, 98, 103, 104, 105, 109, 111], [5, 11, 13, 14, 21, 24, 26, 27, 31, 32  …  67, 70, 71, 93, 96, 100, 101, 106, 110, 113]]
#  [[3, 5, 6, 8, 12, 19, 20, 25, 39, 41  …  79, 82, 91, 94, 97, 98, 100, 101, 110, 114], [16, 17, 18, 24, 29, 30, 34, 35, 42, 43  …  86, 87, 88, 90, 93, 95, 102, 105, 111, 112], [1, 7, 11, 13, 14, 22, 23, 33, 37, 38  …  81, 92, 96, 99, 103, 104, 106, 107, 109, 115], [2, 4, 9, 10, 15, 21, 26, 27, 28, 31  …  64, 67, 69, 74, 76, 80, 85, 89, 108, 113]]

# %%
nlvdis = [10; 15] ; metric = ["mahal"]
h = [1; 2; 6; Inf] ; k = [30; 50; 100]
nlv = 0:15
pars = mpar(nlvdis = nlvdis, metric = metric,
    h = h, k = k)
# Out:
# (nlvdis = Any[10, 15, 10, 15, 10, 15, 10, 15, 10, 15  …  10, 15, 10, 15, 10, 15, 10, 15, 10, 15], metric = Any["mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"  …  "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"], h = Any[1.0, 1.0, 2.0, 2.0, 6.0, 6.0, Inf, Inf, 1.0, 1.0  …  Inf, Inf, 1.0, 1.0, 2.0, 2.0, 6.0, 6.0, Inf, Inf], k = Any[30, 30, 30, 30, 30, 30, 30, 30, 50, 50  …  50, 50, 100, 100, 100, 100, 100, 100, 100, 100])

# %%
length(pars[1])
# Out:
# 24

# %%
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = rmsep, fun = lwplsr, nlv = nlv,
    pars = pars, verbose = false).res
# Out:
# 384×6 DataFrame
#  Row │ nlv    nlvdis  metric  h    k    y1
#      │ Int64  Any     Any     Any  Any  Float64
# ─────┼──────────────────────────────────────────
#    1 │     0  10      mahal   1.0  30   5.19441
#    2 │     1  10      mahal   1.0  30   1.26473
#    3 │     2  10      mahal   1.0  30   1.20593
#    4 │     3  10      mahal   1.0  30   1.2514
#    5 │     4  10      mahal   1.0  30   1.24817
#    6 │     5  10      mahal   1.0  30   1.43099
#    7 │     6  10      mahal   1.0  30   1.49191
#    8 │     7  10      mahal   1.0  30   1.56427
#   ⋮  │   ⋮      ⋮       ⋮      ⋮    ⋮      ⋮
#  378 │     9  15      mahal   Inf  100  2.10789
#  379 │    10  15      mahal   Inf  100  2.13649
#  380 │    11  15      mahal   Inf  100  2.18378
#  381 │    12  15      mahal   Inf  100  2.26949
#  382 │    13  15      mahal   Inf  100  2.44593
#  383 │    14  15      mahal   Inf  100  2.57584
#  384 │    15  15      mahal   Inf  100  2.63697
#                                 369 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    nlvdis  metric  h    k    y1
#      │ Int64  Any     Any     Any  Any  Float64
# ─────┼──────────────────────────────────────────
#    3 │     2  10      mahal   1.0  30   1.20593

# %%
group = string.("nvldis=", res.nlvdis, " h=", res.h,
    " k=", res.k)
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel ="Nb. LVs", ylabel = "RMSEP").f
# Out:
# Figure()

# %%
fm = lwplsr(Xtrain, ytrain; nlvdis = res.nlvdis[u],
    metric = res.metric[u], h = res.h[u], k = res.k[u],
    nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
# Out:
# rmsep(pred, ytest) = [0.931208174412879;;]
# 1×1 Matrix{Float64}:
#  0.931208174412879

# %%
plotxy(vec(pred), ytest; resolution = (500, 400),
    color = (:red, .5), bisect = true,
    xlabel = "Prediction", ylabel = "Observed (Test)").f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
