# %%
using JLD2, CairoMakie
using Jchemo, JchemoData
using Loess

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/tecator.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot = nro(X)
# Out:
# 178

# %%
@head X
# Out:
# ... (178, 100)
# 3×100 DataFrame
#  Row │ 850      852      854      856      858      860      862      864      ⋯
#      │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2.61776  2.61814  2.61859  2.61912  2.61981  2.62071  2.62186  2.62334  ⋯
#    2 │ 2.83454  2.83871  2.84283  2.84705  2.85138  2.85587  2.8606   2.86566
#    3 │ 2.58284  2.58458  2.58629  2.58808  2.58996  2.59192  2.59401  2.59627
#                                                               92 columns omitted

# %%
@head Y
# Out:
# ... (178, 4)
# 3×4 DataFrame
#  Row │ water    fat      protein  typ
#      │ Float64  Float64  Float64  String
# ─────┼───────────────────────────────────
#    1 │    60.5     22.5     16.7  train
#    2 │    46.0     40.1     13.5  train
#    3 │    71.0      8.4     20.5  train

# %%
summ(Y)
# Out:
# (res = 4×7 DataFrame
#  Row │ variable  mean    std     min   max   n      nmissing
#      │ Symbol    Union…  Union…  Any   Any   Int64  Int64
# ─────┼───────────────────────────────────────────────────────
#    1 │ water     63.046  9.784   39.3  76.6    178         0
#    2 │ fat       18.378  12.629  0.9   49.1    178         0
#    3 │ protein   17.634  2.996   11.0  21.8    178         0
#    4 │ typ                       test  val     178         0, ntot = 178)

# %%
namy = names(Y)[1:3]
# Out:
# 3-element Vector{String}:
#  "water"
#  "fat"
#  "protein"

# %%
typ = Y.typ
tab(typ)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "test"  => 31
#   "train" => 115
#   "val"   => 32

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 100-element Vector{Float64}:
#   850.0
#   852.0
#   854.0
#   856.0
#   858.0
#   860.0
#   862.0
#   864.0
#   866.0
#   868.0
#     ⋮
#  1032.0
#  1034.0
#  1036.0
#  1038.0
#  1040.0
#  1042.0
#  1044.0
#  1046.0
#  1048.0

# %%
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
f = 15 ; pol = 3 ; d = 2
Xp = savgol(snv(X); f = f, pol = pol, d = d)

plotsp(Xp, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = typ .== "train"
Xtrain = Xp[s, :]
Ytrain = Y[s, namy]
Xtest = rmrow(Xp, s)
Ytest = rmrow(Y[:, namy], s)
ntrain = nro(Xtrain)
ntest = nro(Xtest)
ntot = ntrain + ntest
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 178, ntrain = 115, ntest = 63)

# %%
j = 2
nam = namy[j]    # y-variable
ytrain = Ytrain[:, nam]
ytest = Ytest[:, nam]
# Out:
# 63-element Vector{Float64}:
#  29.8
#   1.4
#   4.6
#  11.0
#  17.0
#  22.4
#  27.9
#  46.5
#   6.1
#   2.0
#   ⋮
#  18.1
#  19.4
#  24.8
#  27.2
#  28.4
#  31.3
#  33.8
#  35.5
#  42.5

# %%
gamma = 100
nlv = 15
fm = kplsr(Xtrain, ytrain; gamma = gamma,
    nlv = nlv) ;
# Or Direct KPLSR (Bennet 2003):
#fm = dkplsr(Xtrain, ytrain; gamma = gamma, nlv = nlv) ;
pnames(fm)
# Out:
# (:X, :Kt, :T, :C, :U, :R, :D, :DKt, :vtot, :xscales, :ymeans, :yscales, :weights, :kern, :dots, :iter)

# %%
pred = Jchemo.predict(fm, Xtest).pred
# Out:
# 63×1 Matrix{Float64}:
#  30.27263234256402
#   1.2491123455532076
#   4.471039088166272
#  11.010875159204154
#  15.55102248756084
#  22.109610523844452
#  27.615505753161433
#  46.56310162831603
#   5.879362956252525
#   1.75267691270113
#   ⋮
#  17.972585617952642
#  19.578168043161426
#  23.82634859477296
#  27.561395558864078
#  28.42422859344629
#  29.955350999827566
#  33.70752115794052
#  36.07302569843918
#  42.33392844914148

# %%
Jchemo.predict(fm, Xtest; nlv = 2).pred
# Out:
# 63×1 Matrix{Float64}:
#  29.321351662006073
#   2.1620054421182253
#   5.685860978803001
#  10.607528071290865
#  15.113351653297922
#  19.538735864839552
#  26.05719364662251
#  48.59823739068679
#   7.379497041126664
#   2.5403172244964694
#   ⋮
#  17.351751192270747
#  17.649479049893557
#  20.875062275427915
#  28.029665285832124
#  28.579756342019806
#  31.632916286801013
#  35.99900778697405
#  39.2088382182405
#  46.42134811762169

# %%
Jchemo.predict(fm, Xtest; nlv = 0:2).pred
# Out:
# 3-element Vector{Matrix{Float64}}:
#  [18.358260869565218; 18.358260869565218; … ; 18.358260869565218; 18.358260869565218;;]
#  [26.86433358705382; 4.121767055771366; … ; 36.33040026195724; 45.001339268850415;;]
#  [29.321351662006073; 2.1620054421182253; … ; 39.2088382182405; 46.42134811762169;;]

# %%
rmsep(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  0.5511112753961344

# %%
bias(pred, ytest)
# Out:
# 1×1 Matrix{Float64}:
#  -0.1541310197643315

# %%
mse(pred, ytest)
# Out:
# 1×10 DataFrame
#  Row │ nam     msep     rmsep    sep      bias     cor2     r2       rpd       ⋯
#      │ String  Float64  Float64  Float64  Float64  Float64  Float64  Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ y1        0.304    0.551    0.529   -0.154    0.998    0.998   22.995   ⋯
#                                                                2 columns omitted

# %%
r = residreg(pred, ytest) # residuals
# Out:
# 63×1 Matrix{Float64}:
#  -0.47263234256401887
#   0.1508876544467923
#   0.12896091183372782
#  -0.010875159204154272
#   1.4489775124391606
#   0.29038947615554633
#   0.28449424683856606
#  -0.0631016283160335
#   0.22063704374747495
#   0.2473230872988701
#   ⋮
#   0.127414382047359
#  -0.17816804316142765
#   0.9736514052270415
#  -0.3613955588640785
#  -0.024228593446292024
#   1.344649000172435
#   0.09247884205947798
#  -0.5730256984391815
#   0.16607155085851844

# %%
zpred = vec(pred)
f, ax = plotxy(zpred, ytest;
    xlabel = "Predicted", ylabel = "Observed",
    resolution = (500, 400))
zfm = loess(zpred, ytest; span = 2/3) ;
pred_loess = Loess.predict(zfm, sort(zpred))
lines!(ax, sort(zpred), pred_loess; color = :red)
ablines!(ax, 0, 1; color = :grey)
f
# Out:
# Figure()

# %%
zr = vec(r)
f, ax = plotxy(ytest, zr; color = (:blue, .5),
    resolution = (500, 400),
    xlabel = "Observed (Test)", ylabel = "Residual")
zfm = loess(ytest, zr; span = 2/3) ;
pred_loess = Loess.predict(zfm, sort(ytest))
lines!(ax, sort(ytest), pred_loess; color = :red)
hlines!(ax, 0; color = :grey, linestyle = :dashdot)
f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
