# %%
using JLD2, CairoMakie
using Jchemo, JchemoData

# %%
path_pack = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_pack, "data/tecator.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot, p = size(X)
# Out:
# (178, 100)

# %%
@head X
# Out:
# ... (178, 100)
# 3×100 DataFrame
#  Row │ 850      852      854      856      858      860      862      864      ⋯
#      │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2.61776  2.61814  2.61859  2.61912  2.61981  2.62071  2.62186  2.62334  ⋯
#    2 │ 2.83454  2.83871  2.84283  2.84705  2.85138  2.85587  2.8606   2.86566
#    3 │ 2.58284  2.58458  2.58629  2.58808  2.58996  2.59192  2.59401  2.59627
#                                                               92 columns omitted

# %%
@head Y
# Out:
# ... (178, 4)
# 3×4 DataFrame
#  Row │ water    fat      protein  typ
#      │ Float64  Float64  Float64  String
# ─────┼───────────────────────────────────
#    1 │    60.5     22.5     16.7  train
#    2 │    46.0     40.1     13.5  train
#    3 │    71.0      8.4     20.5  train

# %%
summ(Y)
# Out:
# (res = 4×7 DataFrame
#  Row │ variable  mean    std     min   max   n      nmissing
#      │ Symbol    Union…  Union…  Any   Any   Int64  Int64
# ─────┼───────────────────────────────────────────────────────
#    1 │ water     63.046  9.784   39.3  76.6    178         0
#    2 │ fat       18.378  12.629  0.9   49.1    178         0
#    3 │ protein   17.634  2.996   11.0  21.8    178         0
#    4 │ typ                       test  val     178         0, ntot = 178)

# %%
namy = names(Y)[1:3]
# Out:
# 3-element Vector{String}:
#  "water"
#  "fat"
#  "protein"

# %%
typ = Y.typ
tab(typ)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "test"  => 31
#   "train" => 115
#   "val"   => 32

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 100-element Vector{Float64}:
#   850.0
#   852.0
#   854.0
#   856.0
#   858.0
#   860.0
#   862.0
#   864.0
#   866.0
#   868.0
#     ⋮
#  1032.0
#  1034.0
#  1036.0
#  1038.0
#  1040.0
#  1042.0
#  1044.0
#  1046.0
#  1048.0

# %%
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
f = 15 ; pol = 3 ; d = 2
Xp = savgol(snv(X); f = f, pol = pol, d = d)

plotsp(Xp, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = typ .== "train"
Xtrain = Xp[s, :]
Ytrain = Y[s, namy]
Xtest = rmrow(Xp, s)
Ytest = rmrow(Y[:, namy], s)
ntrain = nro(Xtrain)
ntest = nro(Xtest)
ntot = ntrain + ntest
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 178, ntrain = 115, ntest = 63)

# %%
j = 2
nam = namy[j]    # y-variable
ytrain = Ytrain[:, nam]
ytest = Ytest[:, nam]
# Out:
# 63-element Vector{Float64}:
#  29.8
#   1.4
#   4.6
#  11.0
#  17.0
#  22.4
#  27.9
#  46.5
#   6.1
#   2.0
#   ⋮
#  18.1
#  19.4
#  24.8
#  27.2
#  28.4
#  31.3
#  33.8
#  35.5
#  42.5

# %%
segm = segmkf(ntrain, 4; rep = 5)
# Out:
# 5-element Vector{Any}:
#  [[3, 7, 12, 15, 16, 20, 27, 28, 44, 45  …  82, 85, 86, 87, 91, 97, 104, 108, 110, 114], [2, 5, 6, 9, 10, 18, 19, 29, 30, 33  …  66, 73, 74, 81, 83, 84, 88, 95, 99, 103], [4, 8, 11, 21, 22, 24, 25, 31, 34, 39  …  89, 90, 92, 101, 102, 105, 106, 111, 112, 115], [1, 13, 14, 17, 23, 26, 32, 35, 36, 40  …  77, 80, 93, 94, 96, 98, 100, 107, 109, 113]]
#  [[3, 12, 13, 14, 15, 22, 25, 30, 31, 39  …  77, 78, 83, 84, 87, 102, 106, 107, 109, 115], [7, 8, 9, 10, 16, 18, 20, 23, 26, 32  …  50, 52, 62, 68, 86, 95, 97, 105, 110, 111], [2, 4, 5, 6, 24, 28, 36, 38, 41, 46  …  81, 85, 89, 91, 93, 94, 101, 104, 113, 114], [1, 11, 17, 19, 21, 27, 29, 37, 47, 55  …  88, 90, 92, 96, 98, 99, 100, 103, 108, 112]]
#  [[3, 5, 6, 7, 8, 9, 19, 21, 25, 33  …  66, 68, 76, 89, 95, 99, 105, 107, 108, 110], [10, 12, 13, 14, 16, 18, 27, 32, 50, 58  …  90, 91, 94, 96, 101, 102, 106, 111, 112, 115], [4, 11, 15, 17, 20, 24, 28, 29, 36, 39  …  79, 81, 82, 92, 93, 98, 100, 104, 109, 114], [1, 2, 22, 23, 26, 30, 31, 35, 37, 38  …  67, 73, 75, 84, 85, 86, 88, 97, 103, 113]]
#  [[7, 10, 14, 15, 24, 38, 52, 53, 58, 60  …  87, 92, 93, 98, 103, 104, 110, 111, 114, 115], [1, 3, 4, 12, 17, 18, 20, 22, 25, 26  …  74, 79, 80, 91, 95, 97, 101, 102, 106, 112], [6, 11, 13, 16, 21, 28, 29, 30, 31, 32  …  65, 70, 76, 82, 86, 90, 94, 99, 107, 108], [2, 5, 8, 9, 19, 23, 27, 39, 41, 44  …  81, 83, 84, 88, 89, 96, 100, 105, 109, 113]]
#  [[1, 2, 6, 7, 10, 11, 15, 22, 34, 35  …  81, 83, 84, 85, 90, 94, 96, 100, 102, 105], [8, 9, 18, 29, 32, 33, 37, 41, 42, 44  …  77, 79, 86, 87, 88, 89, 91, 97, 98, 101], [3, 13, 16, 21, 23, 24, 28, 30, 31, 36  …  76, 82, 93, 95, 104, 109, 111, 113, 114, 115], [4, 5, 12, 14, 17, 19, 20, 25, 26, 27  …  78, 80, 92, 99, 103, 106, 107, 108, 110, 112]]

# %%
nlvdis = [10; 15] ; metric = ["mahal"]
h = [1; 2; 5; Inf] ; k = [30; 50; 100]
nlv = ["1:5", "1:10"]
pars = mpar(nlvdis = nlvdis, metric = metric,
    h = h, k = k, nlv = nlv)
# Out:
# (nlvdis = Any[10, 15, 10, 15, 10, 15, 10, 15, 10, 15  …  10, 15, 10, 15, 10, 15, 10, 15, 10, 15], metric = Any["mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"  …  "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"], h = Any[1.0, 1.0, 2.0, 2.0, 5.0, 5.0, Inf, Inf, 1.0, 1.0  …  Inf, Inf, 1.0, 1.0, 2.0, 2.0, 5.0, 5.0, Inf, Inf], k = Any[30, 30, 30, 30, 30, 30, 30, 30, 50, 50  …  50, 50, 100, 100, 100, 100, 100, 100, 100, 100], nlv = Any["1:5", "1:5", "1:5", "1:5", "1:5", "1:5", "1:5", "1:5", "1:5", "1:5"  …  "1:10", "1:10", "1:10", "1:10", "1:10", "1:10", "1:10", "1:10", "1:10", "1:10"])

# %%
length(pars[1])
# Out:
# 48

# %%
res = gridcv(Xtrain, ytrain; segm = segm,
    score = rmsep, fun = lwplsravg,
    pars = pars, verbose = false).res
# Out:
# 48×6 DataFrame
#  Row │ nlvdis  metric  h    k    nlv   y1
#      │ Any     Any     Any  Any  Any   Float64
# ─────┼─────────────────────────────────────────
#    1 │ 10      mahal   1.0  30   1:5   1.1136
#    2 │ 15      mahal   1.0  30   1:5   1.25036
#    3 │ 10      mahal   2.0  30   1:5   1.19223
#    4 │ 15      mahal   2.0  30   1:5   1.33624
#    5 │ 10      mahal   5.0  30   1:5   1.2871
#    6 │ 15      mahal   5.0  30   1:5   1.45182
#    7 │ 10      mahal   Inf  30   1:5   1.46903
#    8 │ 15      mahal   Inf  30   1:5   1.62135
#   ⋮  │   ⋮       ⋮      ⋮    ⋮    ⋮       ⋮
#   42 │ 15      mahal   1.0  100  1:10  1.56349
#   43 │ 10      mahal   2.0  100  1:10  1.6512
#   44 │ 15      mahal   2.0  100  1:10  1.72762
#   45 │ 10      mahal   5.0  100  1:10  1.89452
#   46 │ 15      mahal   5.0  100  1:10  1.9331
#   47 │ 10      mahal   Inf  100  1:10  2.13861
#   48 │ 15      mahal   Inf  100  1:10  2.1523
#                                 33 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlvdis  metric  h    k    nlv  y1
#      │ Any     Any     Any  Any  Any  Float64
# ─────┼────────────────────────────────────────
#    1 │ 10      mahal   1.0  30   1:5   1.1136

# %%
fm = lwplsravg(Xtrain, ytrain; nlvdis = res.nlvdis[u],
    metric = res.metric[u], h = res.h[u], k = res.k[u],
    nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
# Out:
# rmsep(pred, ytest) = [0.8389601295204554;;]
# 1×1 Matrix{Float64}:
#  0.8389601295204554

# %%
plotxy(vec(pred), ytest; resolution = (500, 400),
    color = (:red, .5), bisect = true,
    xlabel = "Prediction", ylabel = "Observed (Test)").f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
