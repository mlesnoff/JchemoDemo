# %%
using JLD2, CairoMakie, StatsBase
using Jchemo, JchemoData
using FreqTables

# %%
path_jdat = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_jdat, "data/challenge2018.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot, p = size(X)
# Out:
# (4075, 680)

# %%
@head X
# Out:
# ... (4075, 680)
# 3×680 DataFrame
#  Row │ 1120      1122      1124      1126      1128      1130      1132      1 ⋯
#      │ Float64   Float64   Float64   Float64   Float64   Float64   Float64   F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 0.597482  0.595978  0.593623  0.59084   0.587451  0.583092  0.578666  0 ⋯
#    2 │ 0.954192  0.953237  0.952002  0.950426  0.948382  0.946138  0.943543  0
#    3 │ 0.611137  0.609566  0.60743   0.604767  0.601434  0.597316  0.592598  0
#                                                              673 columns omitted

# %%
@head Y
# Out:
# ... (4075, 4)
# 3×4 DataFrame
#  Row │ typ     label               conc     test
#      │ String  String              Float64  Int64
# ─────┼────────────────────────────────────────────
#    1 │ FRG     wheat (ung)         12.74        0
#    2 │ MPW     milk powder & whey  35.7212      0
#    3 │ FRG     wheat (ung)         12.0         0

# %%
summ(Y)
# Out:
# (res = 4×7 DataFrame
#  Row │ variable  mean    std     min          max          n      nmissing
#      │ Symbol    Union…  Union…  Any          Any          Int64  Int64
# ─────┼─────────────────────────────────────────────────────────────────────
#    1 │ typ                       ANF          TTS           4075         0
#    2 │ label                     animal feed  wheat (ung)   4075         0
#    3 │ conc      31.93   20.348  2.766        76.604        4075         0
#    4 │ test      0.092   0.289   0            1             4075         0, ntot = 4075)

# %%
y = Y.conc
typ = Y.typ
label = Y.label
test = Y.test
tab(test)
# Out:
# OrderedCollections.OrderedDict{Int64, Int64} with 2 entries:
#   0 => 3701
#   1 => 374

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 680-element Vector{Float64}:
#  1120.0
#  1122.0
#  1124.0
#  1126.0
#  1128.0
#  1130.0
#  1132.0
#  1134.0
#  1136.0
#  1138.0
#     ⋮
#  2462.0
#  2464.0
#  2466.0
#  2468.0
#  2470.0
#  2472.0
#  2474.0
#  2476.0
#  2478.0

# %%
freqtable(string.(typ, "-", Y.label))
# Out:
# 10-element Named Vector{Int64}
# Dim1                    │
# ────────────────────────┼────
# ANF-animal feed         │ 391
# CLZ-rapeseed(ung)       │ 420
# CNG-corn gluten         │ 395
# EHH-grass silage        │ 422
# FFS-full fat soya       │ 432
# FRG-wheat (ung)         │ 411
# MPW-milk powder & whey  │ 410
# PEE-maize wp            │ 407
# SFG-sun flower seed(gr) │ 281
# TTS-soya meal           │ 506

# %%
freqtable(typ, test)
# Out:
# 10×2 Named Matrix{Int64}
# Dim1 ╲ Dim2 │   0    1
# ────────────┼─────────
# ANF         │ 351   40
# CLZ         │ 378   42
# CNG         │ 356   39
# EHH         │ 380   42
# FFS         │ 397   35
# FRG         │ 371   40
# MPW         │ 372   38
# PEE         │ 367   40
# SFG         │ 272    9
# TTS         │ 457   49

# %%
plotsp(X, wl_num; nsamp = 30).f
# Out:
# Figure()

# %%
f = 21 ; pol = 3 ; d = 2
Xp = savgol(snv(X); f = f, pol = pol, d = d) ;

plotsp(Xp, wl_num; nsamp = 30).f
# Out:
# Figure()

# %%
s = Bool.(test)
Xtrain = rmrow(Xp, s)
ytrain = rmrow(y, s)
Xtest = Xp[s, :]
ytest = y[s]
ntrain = nro(Xtrain)
ntest = nro(Xtest)
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 4075, ntrain = 3701, ntest = 374)

# %%
nval = 300
ncal = ntrain - nval
s = sample(1:ntrain, nval; replace = false)
Xcal = rmrow(Xtrain, s)
ycal = rmrow(ytrain, s)
Xval = Xtrain[s, :]
yval = ytrain[s]
(ntot = ntot, ntrain, ntest, ncal, nval)
# Out:
# (ntot = 4075, ntrain = 3701, ntest = 374, ncal = 3401, nval = 300)

# %%
nlvdis = [15; 25] ; metric = ["mahal"]
h = [1; 2; 4; 6; Inf]
k = [150; 200; 350; 500; 1000]
nlv = 1:20
pars = mpar(nlvdis = nlvdis, metric = metric,
    h = h, k = k)
# Out:
# (nlvdis = Any[15, 25, 15, 25, 15, 25, 15, 25, 15, 25  …  15, 25, 15, 25, 15, 25, 15, 25, 15, 25], metric = Any["mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"  …  "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"], h = Any[1.0, 1.0, 2.0, 2.0, 4.0, 4.0, 6.0, 6.0, Inf, Inf  …  1.0, 1.0, 2.0, 2.0, 4.0, 4.0, 6.0, 6.0, Inf, Inf], k = Any[150, 150, 150, 150, 150, 150, 150, 150, 150, 150  …  1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000])

# %%
length(pars[1])
# Out:
# 50

# %%
res = gridscorelv(Xcal, ycal, Xval, yval;
    score = rmsep, fun = lwplsr, nlv = nlv, pars = pars,
    verbose = false)
# Out:
# 1000×6 DataFrame
#   Row │ nlvdis  metric  h    k     nlv    y1
#       │ Any     Any     Any  Any   Int64  Float64
# ──────┼────────────────────────────────────────────
#     1 │ 15      mahal   1.0  150       1  1.33055
#     2 │ 15      mahal   1.0  150       2  1.04439
#     3 │ 15      mahal   1.0  150       3  0.944771
#     4 │ 15      mahal   1.0  150       4  0.857306
#     5 │ 15      mahal   1.0  150       5  0.806682
#     6 │ 15      mahal   1.0  150       6  0.758308
#     7 │ 15      mahal   1.0  150       7  0.738319
#     8 │ 15      mahal   1.0  150       8  0.702632
#   ⋮   │   ⋮       ⋮      ⋮    ⋮      ⋮       ⋮
#   994 │ 25      mahal   Inf  1000     14  1.13142
#   995 │ 25      mahal   Inf  1000     15  1.08731
#   996 │ 25      mahal   Inf  1000     16  1.06454
#   997 │ 25      mahal   Inf  1000     17  1.04124
#   998 │ 25      mahal   Inf  1000     18  1.02317
#   999 │ 25      mahal   Inf  1000     19  1.00724
#  1000 │ 25      mahal   Inf  1000     20  1.00533
#                                    985 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlvdis  metric  h    k    nlv    y1
#      │ Any     Any     Any  Any  Int64  Float64
# ─────┼───────────────────────────────────────────
#  420 │ 15      mahal   1.0  350     20  0.659228

# %%
group = string.("nlvdis=", res.nlvdis, ",h=", res.h, ",k=", res.k)
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel ="Nb. LVs", ylabel = "RMSEP").f
# Out:
# Figure()

# %%
fm = lwplsr(Xtrain, ytrain; nlvdis = res.nlvdis[u],
    metric = res.metric[u], h = res.h[u], k = res.k[u],
    nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
# Out:
# rmsep(pred, ytest) = [0.7544955527944915;;]
# 1×1 Matrix{Float64}:
#  0.7544955527944915

# %%
plotxy(vec(pred), ytest; resolution = (500, 400),
    color = (:red, .5), bisect = true,
    xlabel = "Prediction", ylabel = "Observed (Test)").f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
