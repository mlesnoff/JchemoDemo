# %%
using JLD2, CairoMakie
using Jchemo, JchemoData

# %%
path_pack = dirname(dirname(pathof(JchemoData)))
db = joinpath(path_pack, "data/tecator.jld2")
@load db dat
pnames(dat)
# Out:
# (:X, :Y)

# %%
X = dat.X
Y = dat.Y
ntot, p = size(X)
# Out:
# (178, 100)

# %%
@head X
# Out:
# ... (178, 100)
# 3×100 DataFrame
#  Row │ 850      852      854      856      858      860      862      864      ⋯
#      │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2.61776  2.61814  2.61859  2.61912  2.61981  2.62071  2.62186  2.62334  ⋯
#    2 │ 2.83454  2.83871  2.84283  2.84705  2.85138  2.85587  2.8606   2.86566
#    3 │ 2.58284  2.58458  2.58629  2.58808  2.58996  2.59192  2.59401  2.59627
#                                                               92 columns omitted

# %%
@head Y
# Out:
# ... (178, 4)
# 3×4 DataFrame
#  Row │ water    fat      protein  typ
#      │ Float64  Float64  Float64  String
# ─────┼───────────────────────────────────
#    1 │    60.5     22.5     16.7  train
#    2 │    46.0     40.1     13.5  train
#    3 │    71.0      8.4     20.5  train

# %%
summ(Y)
# Out:
# (res = 4×7 DataFrame
#  Row │ variable  mean    std     min   max   n      nmissing
#      │ Symbol    Union…  Union…  Any   Any   Int64  Int64
# ─────┼───────────────────────────────────────────────────────
#    1 │ water     63.046  9.784   39.3  76.6    178         0
#    2 │ fat       18.378  12.629  0.9   49.1    178         0
#    3 │ protein   17.634  2.996   11.0  21.8    178         0
#    4 │ typ                       test  val     178         0, ntot = 178)

# %%
namy = names(Y)[1:3]
# Out:
# 3-element Vector{String}:
#  "water"
#  "fat"
#  "protein"

# %%
typ = Y.typ
tab(typ)
# Out:
# OrderedCollections.OrderedDict{String, Int64} with 3 entries:
#   "test"  => 31
#   "train" => 115
#   "val"   => 32

# %%
wl = names(X)
wl_num = parse.(Float64, wl)
# Out:
# 100-element Vector{Float64}:
#   850.0
#   852.0
#   854.0
#   856.0
#   858.0
#   860.0
#   862.0
#   864.0
#   866.0
#   868.0
#     ⋮
#  1032.0
#  1034.0
#  1036.0
#  1038.0
#  1040.0
#  1042.0
#  1044.0
#  1046.0
#  1048.0

# %%
plotsp(X, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
f = 15 ; pol = 3 ; d = 2
Xp = savgol(snv(X); f = f, pol = pol, d = d)

plotsp(Xp, wl_num;
    xlabel = "Wavelength (nm)", ylabel = "Absorbance").f
# Out:
# Figure()

# %%
s = typ .== "train"
Xtrain = Xp[s, :]
Ytrain = Y[s, namy]
Xtest = rmrow(Xp, s)
Ytest = rmrow(Y[:, namy], s)
ntrain = nro(Xtrain)
ntest = nro(Xtest)
ntot = ntrain + ntest
(ntot = ntot, ntrain, ntest)
# Out:
# (ntot = 178, ntrain = 115, ntest = 63)

# %%
j = 2
nam = namy[j]    # y-variable
ytrain = Ytrain[:, nam]
ytest = Ytest[:, nam]
# Out:
# 63-element Vector{Float64}:
#  29.8
#   1.4
#   4.6
#  11.0
#  17.0
#  22.4
#  27.9
#  46.5
#   6.1
#   2.0
#   ⋮
#  18.1
#  19.4
#  24.8
#  27.2
#  28.4
#  31.3
#  33.8
#  35.5
#  42.5

# %%
segm = segmkf(ntrain, 4; rep = 5)
# Out:
# 5-element Vector{Any}:
#  [[2, 7, 17, 21, 23, 27, 32, 34, 37, 38  …  72, 74, 77, 79, 92, 93, 98, 99, 101, 115], [3, 4, 5, 9, 10, 19, 29, 39, 40, 45  …  83, 87, 88, 90, 91, 94, 100, 104, 107, 108], [11, 12, 13, 14, 15, 20, 22, 24, 25, 26  …  64, 75, 78, 85, 86, 95, 97, 103, 106, 110], [1, 6, 8, 16, 18, 28, 30, 31, 33, 35  …  84, 89, 96, 102, 105, 109, 111, 112, 113, 114]]
#  [[2, 4, 8, 11, 18, 24, 28, 33, 36, 42  …  82, 90, 92, 94, 95, 96, 103, 104, 105, 108], [1, 9, 17, 19, 26, 27, 29, 30, 35, 38  …  77, 79, 83, 84, 86, 88, 102, 107, 111, 112], [3, 5, 10, 14, 16, 20, 22, 25, 32, 34  …  78, 80, 81, 85, 89, 97, 98, 99, 106, 110], [6, 7, 12, 13, 15, 21, 23, 31, 37, 39  …  75, 87, 91, 93, 100, 101, 109, 113, 114, 115]]
#  [[4, 8, 14, 16, 20, 25, 28, 30, 33, 40  …  71, 83, 84, 86, 97, 98, 106, 107, 109, 112], [1, 2, 5, 9, 13, 22, 23, 31, 34, 38  …  81, 87, 89, 92, 95, 101, 105, 108, 110, 113], [6, 15, 17, 21, 29, 32, 41, 42, 44, 45  …  78, 80, 88, 90, 93, 96, 99, 100, 102, 104], [3, 7, 10, 11, 12, 18, 19, 24, 26, 27  …  61, 66, 82, 85, 91, 94, 103, 111, 114, 115]]
#  [[2, 4, 11, 14, 18, 26, 27, 43, 44, 46  …  84, 89, 91, 97, 99, 100, 107, 109, 110, 113], [6, 8, 9, 10, 16, 19, 20, 23, 28, 29  …  85, 86, 88, 92, 95, 98, 103, 106, 111, 112], [1, 13, 15, 17, 22, 24, 36, 39, 40, 47  …  73, 74, 77, 87, 96, 101, 102, 104, 105, 108], [3, 5, 7, 12, 21, 25, 30, 31, 32, 34  …  69, 71, 72, 78, 81, 90, 93, 94, 114, 115]]
#  [[4, 7, 11, 25, 27, 29, 36, 38, 41, 42  …  90, 96, 97, 99, 101, 103, 105, 113, 114, 115], [2, 3, 5, 12, 13, 18, 31, 33, 35, 37  …  72, 74, 84, 88, 95, 102, 106, 110, 111, 112], [1, 8, 14, 16, 20, 22, 28, 30, 32, 34  …  79, 81, 82, 86, 87, 91, 93, 107, 108, 109], [6, 9, 10, 15, 17, 19, 21, 23, 24, 26  …  78, 80, 83, 85, 89, 92, 94, 98, 100, 104]]

# %%
nlvdis = [10; 15] ; metric = ["mahal"]
h = [1; 2; 6; Inf] ; k = [30; 50; 100]
nlv = 0:15
pars = mpar(nlvdis = nlvdis, metric = metric,
    h = h, k = k)
# Out:
# (nlvdis = Any[10, 15, 10, 15, 10, 15, 10, 15, 10, 15  …  10, 15, 10, 15, 10, 15, 10, 15, 10, 15], metric = Any["mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"  …  "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal", "mahal"], h = Any[1.0, 1.0, 2.0, 2.0, 6.0, 6.0, Inf, Inf, 1.0, 1.0  …  Inf, Inf, 1.0, 1.0, 2.0, 2.0, 6.0, 6.0, Inf, Inf], k = Any[30, 30, 30, 30, 30, 30, 30, 30, 50, 50  …  50, 50, 100, 100, 100, 100, 100, 100, 100, 100])

# %%
length(pars[1])
# Out:
# 24

# %%
res = gridcvlv(Xtrain, ytrain; segm = segm,
    score = rmsep, fun = lwplsr, nlv = nlv,
    pars = pars, verbose = false).res
# Out:
# 384×6 DataFrame
#  Row │ nlv    nlvdis  metric  h    k    y1
#      │ Int64  Any     Any     Any  Any  Float64
# ─────┼──────────────────────────────────────────
#    1 │     0  10      mahal   1.0  30   5.4447
#    2 │     1  10      mahal   1.0  30   1.43929
#    3 │     2  10      mahal   1.0  30   1.31865
#    4 │     3  10      mahal   1.0  30   1.34752
#    5 │     4  10      mahal   1.0  30   1.41417
#    6 │     5  10      mahal   1.0  30   1.44438
#    7 │     6  10      mahal   1.0  30   1.64464
#    8 │     7  10      mahal   1.0  30   1.64443
#   ⋮  │   ⋮      ⋮       ⋮      ⋮    ⋮      ⋮
#  378 │     9  15      mahal   Inf  100  2.32057
#  379 │    10  15      mahal   Inf  100  2.31088
#  380 │    11  15      mahal   Inf  100  2.3649
#  381 │    12  15      mahal   Inf  100  2.49603
#  382 │    13  15      mahal   Inf  100  2.65408
#  383 │    14  15      mahal   Inf  100  2.83076
#  384 │    15  15      mahal   Inf  100  2.79705
#                                 369 rows omitted

# %%
u = findall(res.y1 .== minimum(res.y1))[1]
res[u, :]
# Out:
# DataFrameRow
#  Row │ nlv    nlvdis  metric  h    k    y1
#      │ Int64  Any     Any     Any  Any  Float64
# ─────┼──────────────────────────────────────────
#    3 │     2  10      mahal   1.0  30   1.31865

# %%
group = string.("nvldis=", res.nlvdis, " h=", res.h,
    " k=", res.k)
plotgrid(res.nlv, res.y1, group; step = 2,
    xlabel ="Nb. LVs", ylabel = "RMSEP").f
# Out:
# Figure()

# %%
fm = lwplsr(Xtrain, ytrain; nlvdis = res.nlvdis[u],
    metric = res.metric[u], h = res.h[u], k = res.k[u],
    nlv = res.nlv[u]) ;
pred = Jchemo.predict(fm, Xtest).pred
@show rmsep(pred, ytest)
# Out:
# rmsep(pred, ytest) = [0.931208174412879;;]
# 1×1 Matrix{Float64}:
#  0.931208174412879

# %%
plotxy(vec(pred), ytest; resolution = (500, 400),
    color = (:red, .5), bisect = true,
    xlabel = "Prediction", ylabel = "Observed (Test)").f
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
